# %% [markdown]
# Make a python script that can automate the process for creating publication entries. If possible, the script should get the author names, article title, journal name, publication date, and abstract and compile it into a templated markdown file for insertion into the publications page.
#
# For the publications: we can stick with pubs starting from 2018 or 2019 since that's when the lab started up. There will be a relatively large number of publications here, so it would probably be ideal if this could be automated to some degree (like a script that could automatically parse a google scholar entry or DOI into a properly formatted markdown file that matches the template for the wowchemy publications page.

# %%
import os
import requests
import sys
import json

name_to_account = {
    'Tod A. Pascal': 'admin',
}

def replace_with_dictionary(array, dictionary):
    # Iterate over each string in the array
    for i in range(len(array)):
        # If the string is a key in the dictionary, replace it with the corresponding value
        if array[i] in dictionary:
            array[i] = dictionary[array[i]]
    return array

def fetch_data(doi):
    """Fetch publication data from CrossRef API."""
    url = f"https://api.crossref.org/works/{doi}"
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()['message']
    else:
        print("Failed to fetch data.")
        sys.exit(1)

def create_files(pub_data, dir_name):
    """Create directory and files based on publication data."""
    # Ensure valid filenames
    directory = "out"
    valid_dir_name = os.path.join(directory, dir_name.replace("/", "_").replace("\\", "_").replace('"', '').replace(':', '_').replace('?', ''))
    os.makedirs(valid_dir_name, exist_ok=True)

    # Extracting and formatting author list to include only first names
    authors_source = [f"{author.get('given', '')} {author.get('family', '')}" for author in pub_data.get('author', [])]
    authors = authors_source.copy()
    authors = replace_with_dictionary(authors, name_to_account)
    authors_md = "\n- ".join([""] + authors)  # Markdown list format
    
    # Format publication date correctly
    pub_date_parts = pub_data.get('published-print', pub_data.get('published-online', {'date-parts': [[0]]}))['date-parts'][0]
    if len(pub_date_parts) == 3:  # Full date available
        formatted_pub_date = f"{pub_date_parts[0]:04d}-{pub_date_parts[1]:02d}-{pub_date_parts[2]:02d}T00:00:00Z"
    elif len(pub_date_parts) == 2:  # Only year and month available
        formatted_pub_date = f"{pub_date_parts[0]:04d}-{pub_date_parts[1]:02d}-01T00:00:00Z"
    else:  # Only year available
        formatted_pub_date = f"{pub_date_parts[0]:04d}-01-01T00:00:00Z"

    # Edge Case during parsing:
    publication = pub_data.get('container-title', [''])
    if len(publication) == 0:
        publication = ['']
    # Index.md content
    index_content = f"""---
title: "{pub_data.get('title', [''])[0]}"
authors:{authors_md}
date: "{formatted_pub_date}"
doi: "{pub_data.get('DOI', '')}"
abstract: "{pub_data.get('abstract', '').replace('\n', ' ')}"
url_pdf: "{pub_data.get('URL', '')}"
publication: "{publication[0]}"
publication_types: ["article-journal"]
---

Add the publication's full text or supplementary notes here.
"""
    with open(os.path.join(valid_dir_name, "index.md"), "w", encoding='utf-8') as f:
        f.write(index_content)

    # Prepare full names for citation
    bib_authors = ", ".join(authors_source)
    bib_content = f"""@article{{{pub_data.get('DOI', '').replace('/', '_')},
  title = {{{pub_data.get('title', [''])[0]}}},
  author= {{{bib_authors}}},
  journal = {{{publication[0]}}},
  year    = {pub_date_parts[0]},
  volume  = {pub_data.get('volume', '')},
  number  = {pub_data.get('issue', '')},
  doi     = {{{pub_data.get('DOI', '')}}},
  url     = {{{pub_data.get('URL', '')}}}
}}
"""
    with open(os.path.join(valid_dir_name, "cite.bib"), "w", encoding='utf-8') as f:
        f.write(bib_content)

    print(f"Files generated in directory: {valid_dir_name}")




# if __name__ == "__main__":
#     if len(sys.argv) != 2:
#         print("Usage: python fetch_pub_data.py <DOI>")
#         sys.exit(1)
    
#     doi = sys.argv[1]
#     pub_data = fetch_data(doi)

#     # Use title for directory name, or DOI if title is unavailable
#     dir_name = pub_data.get('DOI').split('/')[1]
#     create_files(pub_data, dir_name)

# %%
doi = "10.1021/bi901283p"
pub_data = fetch_data(doi)
dir_name = pub_data.get('DOI').split('/')[1]
create_files(pub_data, dir_name)
# Out:
# Files generated in directory: out/bi901283p

# %% [markdown]
# Script to fetch all DOIs by an author

# %%
# import requests

# def find_papers_by_author(author_name):
#     # Construct the CrossRef API URL for querying papers by author
#     url = f"https://api.crossref.org/works?query.author={author_name}"
    
#     # Make a GET request to the CrossRef API
#     response = requests.get(url)
    
#     # Check if the request was successful (status code 200)
#     if response.status_code == 200:
#         # Parse the JSON response
#         data = response.json()
        
#         # Extract DOIs from the API response
#         dois = [item['DOI'] for item in data['message']['items']]
        
#         return dois
#     else:
#         # If request was not successful, print error message
#         print("Error fetching papers:", response.status_code)
#         return None

# # Example usage:
# author_name = "Tod A. Pascal"
# paper_dois = find_papers_by_author(author_name)
# if paper_dois:
#     print("Papers by", author_name + ":")
#     for doi in paper_dois:
#         print("- DOI:", doi)
# Out:
# Papers by Tod A. Pascal:
# - DOI: 10.1038/s41467-023-37857-3
# - DOI: 10.21203/rs.3.rs-1683269/v1
# - DOI: 10.1021/jp410861h
# - DOI: 10.1021/jp309693d
# - DOI: 10.1021/acs.jpclett.1c02609
# - DOI: 10.1016/j.cmpb.2011.04.006
# - DOI: 10.1039/c6cp03940e
# - DOI: 10.1039/c4cp05316h
# - DOI: 10.1149/ma2022-01381691mtgabs
# - DOI: 10.1063/5.0054314
# - DOI: 10.1039/d2nr05732h
# - DOI: 10.1021/jz200453u
# - DOI: 10.1007/s40262-012-0014-9
# - DOI: 10.1063/1.3456543
# - DOI: 10.1073/pnas.1108073108
# - DOI: 10.1149/ma2014-02/1/17
# - DOI: 10.1149/ma2017-01/43/1984
# - DOI: 10.1016/j.commatsci.2012.12.024
# - DOI: 10.2139/ssrn.236033
# - DOI: 10.1149/ma2016-03/2/422

# %%
for doi in paper_dois:
    pub_data = fetch_data(doi)
    dir_name = pub_data.get('DOI').split('/')[1]
    create_files(pub_data, dir_name)
# Out:
# Files generated in directory: s41467-023-37857-3
# Files generated in directory: rs.3.rs-1683269
# Files generated in directory: jp410861h
# Files generated in directory: jp309693d
# Files generated in directory: acs.jpclett.1c02609
# Files generated in directory: j.cmpb.2011.04.006
# Files generated in directory: c6cp03940e
# Files generated in directory: c4cp05316h
# Files generated in directory: ma2022-01381691mtgabs
# Files generated in directory: 5.0054314
# Files generated in directory: d2nr05732h
# Files generated in directory: jz200453u
# Files generated in directory: s40262-012-0014-9
# Files generated in directory: 1.3456543
# Files generated in directory: pnas.1108073108
# Files generated in directory: ma2014-02
# Files generated in directory: ma2017-01
# Files generated in directory: j.commatsci.2012.12.024
# Files generated in directory: ssrn.236033
# Files generated in directory: ma2016-03

# %%
import os

def find_main_versions(directory):
    main_versions = {}
    for filename in os.listdir(directory):
        if filename.endswith(".pdf") and filename.startswith(tuple(str(num) for num in range(10))):
            if "_si" not in filename and "_SM" not in filename and "-si" not in filename and "-mmc1" not in filename and ".sapp" not in filename:
                paper_number = filename.split(".")[0]
                if paper_number not in main_versions:
                    main_versions[paper_number] = filename
    return main_versions

# Example usage:
directory = "published"
main_versions = find_main_versions(directory)
print("Main versions of papers:")
for paper_number, filename in main_versions.items():
    print(f"Paper {paper_number}: {filename}")
# Out:
# Main versions of papers:
# Paper 004: 004.jbc-8829-36.pdf
# Paper 013: 013.nl104227t.pdf
# Paper 003: 003.NanoSciNanoTech.707.pdf
# Paper 059: 059.s41467-021-23603-0.pdf
# Paper 034: 034.c5cp02951a.pdf
# Paper 044: 044.jacs.7b11891.pdf
# Paper 055: 055.s41560-021-00783-z.pdf
# Paper 079: 079.acs.jpcb.2c08843.ms.pdf
# Paper 032: 032.nature14327-s1.pdf
# Paper 068: 068.acsenergylett.1c02723.pdf
# Paper 085: 085.acsami.3c07224.si.pdf
# Paper 069: 069.d1ee03422g.pdf
# Paper 012: 012.jz200453u.pdf
# Paper 054: 054.1-s2.0-S1369702120303382-main.pdf
# Paper 087: 087.jacs.3c05093.si.pdf
# Paper 051: 051.acs.jpclett.9b01835.pdf
# Paper 080: 080.acs.jpclett.2c03942.si.1.pdf
# Paper 067: 067.1-s2.0-S2666386421004537-main.pdf
# Paper 008: 008.JChemPhys_133_134114.pdf
# Paper 046: 046.J. Electrochem. Soc.-2018-Wang-A3487-95.pdf
# Paper 061: 061.acs.nanolett.1c01502.pdf
# Paper 070: 070.acs.nanolett.2c00047.si.pdf
# Paper 083: 083.acs.nanolett.3c01825.si.pdf
# Paper 048: 048.jacs.8b09743.pdf
# Paper 040: 040.nlE7b00249.pdf
# Paper 006: 006.BioChem.bi901283p.pdf
# Paper 017: 017.jp209541e.pdf
# Paper 042: 042.s41467-017-02410-6-SI.pdf
# Paper 053: 053.acsenergylett.0c00643.si.pdf
# Paper 064: 064.acs.jpclett.1c02609.si.pdf
# Paper 084: 084.acsami.3c09627.pdf
# Paper 082: 082.s41563-023-01535-y_ESM.pdf
# Paper 023: 023.025248JCP.pdf
# Paper 038: 038.JECS-2017-Wujcik-A18-27.pdf
# Paper 009: 009.jbc-37753-61.pdf
# Paper 002: 002.BioPhysJ-2006-1463.pdf
# Paper 071: 071.acs.jpclett.2c00770.pdf
# Paper 030: 030.science.831.SM.pdf
# Paper 078: 078.d2nr05732h.ms.pdf
# Paper 015: 015.jz200760n.pdf
# Paper 001: 001.nar-6047.full.pdf
# Paper 058: 058.eabe2265.full.pdf
# Paper 018: 018.jz201612y.pdf
# Paper 041: 041.acs.jpcc.7b05153.pdf
# Paper 036: 036.c6cp03940e1.pdf
# Paper 027: 027.jz500260s.pdf
# Paper 072: 072.pnas.2200392119.pdf
# Paper 021: 021.jp306473u.pdf
# Paper 022: 022.jp309693d.pdf
# Paper 063: 063.PhysRevLett.127.096801.pdf
# Paper 050: 050.1.5109468.pdf
# Paper 074: 074.acs.chemmater.2c00292.pdf
# Paper 020: 020.jp301610b.pdf
# Paper 014: 014.ct200211b.pdf
# Paper 026: 026.066401JCP.pdf
# Paper 016: 016.pnas.1108073108.pdf
# Paper 011: 011.c0cp01549k.pdf
# Paper 037: 037.jp6b04264.pdf
# Paper 047: 047.qt3xn0326x.pdf
# Paper 005: 005.jbc-15835-46.pdf
# Paper 043: 043.PhysRevLett.120.023901.pdf
# Paper 066: 066.PhysRevLett.127.237402.pdf
# Paper 031: 031.C4CP05316H.pdf
# Paper 073: 073.acsnano.2c04595.pdf
# Paper 088: 088.anie202316786-ms.pdf
# Paper 060: 060.jcp5.0054314.pdf
# Paper 035: 035.nl5b02078.pdf
# Paper 052: 052.j.cplett.2019.136811.pdf
# Paper 075: 075.acs.jpclett.2c01020.pdf
# Paper 007: 007.cphc_201000528_sm_miscellaneous_information.pdf
# Paper 081: 081.s41467-023-37857-3.pdf
# Paper 039: 039.c6cp06889h.pdf
# Paper 049: 049.acs.langmuir.8b03528.pdf
# Paper 019: 019.jz3000036.pdf
# Paper 033: 033.aenm.201500285.pdf
# Paper 028: 028.jecs.A1100-6.pdf
# Paper 010: 010.jz101391r.pdf
# Paper 086: 086.pnas.2310714120.ms.pdf
# Paper 045: 045.acs.macromol.7b02573.pdf
# Paper 024: 024.jp310422q.pdf
# Paper 025: 025.commmat_4952.pdf
# Paper 056: 056.jcp.5.0047656.pdf
# Paper 057: 057.1-s2.0-S0167663621001502-main.pdf
# Paper 065: 065.1-s2.0-S0378775321009617-main.pdf
# Paper 062: 062.jacs.1c04272.pdf
# Paper 076: 076.PhysRevApplied.18.054031.pdf
# Paper 077: 077.acsanm.2c05257.pdf
# Paper 029: 029.jp410861h.pdf

# %%
import os

def find_main_and_supplementary_versions(directory):
    main_versions = {}
    supplementary_versions = {}
    for paper_number in range(1, 89):  # Loop from 1 to 88
        padded_number = str(paper_number).zfill(3)  # Zero-pad the number to ensure three digits
        main_file = None
        sup_file1 = None
        sup_file2 = None
        count = 0
        for filename in os.listdir(directory):
            if filename.startswith(padded_number) and filename.endswith(".pdf"):
                count += 1
                if not any(keyword in filename for keyword in ["_si", "_SM", "-si", "-mmc1", ".sapp", "-s1", ".SM", ".si", "_sm", "_Sm", "_SI", "-SI", "-sm", "_ESM"]):
                    main_file = filename
                    # break  # Found main version, exit loop
                else:
                    if sup_file1:
                        sup_file2 = filename
                    else:
                        sup_file1 = filename
        if main_file:
            main_versions[padded_number] = main_file
        if sup_file1:
            if sup_file2:
                supplementary_versions[padded_number] = sup_file1 + ";" + sup_file2
                if count != 3:
                    raise ValueError(f"File number does not checkout 3 for {padded_number}")
            else:
                supplementary_versions[padded_number] = sup_file1
                if count != 2:
                    raise ValueError(f"File number does not checkout 2 for {padded_number}")
        else:
            if count != 1:
                raise ValueError(f"File number does not checkout 1 for {padded_number}")
    return main_versions, supplementary_versions

# Example usage:
directory = "published"
main_versions, supplementary_versions = find_main_and_supplementary_versions(directory)
print("Main versions of papers:")
for paper_number, filename in main_versions.items():
    print(f"Paper {paper_number}: {filename}")

print("Sup versions of papers:")
for paper_number, file_path in supplementary_versions.items():
    print(f"Paper {paper_number}: {file_path}")
# Out:
# Main versions of papers:
# Paper 001: 001.nar-6047.full.pdf
# Paper 002: 002.BioPhysJ-2006-1463.pdf
# Paper 003: 003.NanoSciNanoTech.707.pdf
# Paper 004: 004.jbc-8829-36.pdf
# Paper 005: 005.jbc-15835-46.pdf
# Paper 006: 006.BioChem.bi901283p.pdf
# Paper 007: 007.cphc_201000528.pdf
# Paper 008: 008.JChemPhys_133_134114.pdf
# Paper 009: 009.jbc-37753-61.pdf
# Paper 010: 010.jz101391r.pdf
# Paper 011: 011.c0cp01549k.pdf
# Paper 012: 012.jz200453u.pdf
# Paper 013: 013.nl104227t.pdf
# Paper 014: 014.ct200211b.pdf
# Paper 015: 015.jz200760n.pdf
# Paper 016: 016.pnas.1108073108.pdf
# Paper 017: 017.jp209541e.pdf
# Paper 018: 018.jz201612y.pdf
# Paper 019: 019.jz3000036.pdf
# Paper 020: 020.jp301610b.pdf
# Paper 021: 021.jp306473u.pdf
# Paper 022: 022.jp309693d.pdf
# Paper 023: 023.025248JCP.pdf
# Paper 024: 024.jp310422q.pdf
# Paper 025: 025.commmat_4952.pdf
# Paper 026: 026.066401JCP.pdf
# Paper 027: 027.jz500260s.pdf
# Paper 028: 028.jecs.A1100-6.pdf
# Paper 029: 029.jp410861h.pdf
# Paper 030: 030.science.831.full.pdf
# Paper 031: 031.C4CP05316H.pdf
# Paper 032: 032.nature14327.pdf
# Paper 033: 033.aenm.201500285.pdf
# Paper 034: 034.c5cp02951a.pdf
# Paper 035: 035.nl5b02078.pdf
# Paper 036: 036.c6cp03940e1.pdf
# Paper 037: 037.jp6b04264.pdf
# Paper 038: 038.JECS-2017-Wujcik-A18-27.pdf
# Paper 039: 039.c6cp06889h.pdf
# Paper 040: 040.nlE7b00249.pdf
# Paper 041: 041.acs.jpcc.7b05153.pdf
# Paper 042: 042.s41467-017-02410-6.pdf
# Paper 043: 043.PhysRevLett.120.023901.pdf
# Paper 044: 044.jacs.7b11891.pdf
# Paper 045: 045.acs.macromol.7b02573.pdf
# Paper 046: 046.J. Electrochem. Soc.-2018-Wang-A3487-95.pdf
# Paper 047: 047.qt3xn0326x.pdf
# Paper 048: 048.jacs.8b09743.pdf
# Paper 049: 049.acs.langmuir.8b03528.pdf
# Paper 050: 050.1.5109468.pdf
# Paper 051: 051.acs.jpclett.9b01835.pdf
# Paper 052: 052.j.cplett.2019.136811.pdf
# Paper 053: 053.acsenergylett.0c00643.pdf
# Paper 054: 054.1-s2.0-S1369702120303382-main.pdf
# Paper 055: 055.s41560-021-00783-z.pdf
# Paper 056: 056.jcp.5.0047656.pdf
# Paper 057: 057.1-s2.0-S0167663621001502-main.pdf
# Paper 058: 058.eabe2265.full.pdf
# Paper 059: 059.s41467-021-23603-0.pdf
# Paper 060: 060.jcp5.0054314.pdf
# Paper 061: 061.acs.nanolett.1c01502.pdf
# Paper 062: 062.jacs.1c04272.pdf
# Paper 063: 063.PhysRevLett.127.096801.pdf
# Paper 064: 064.acs.jpclett.1c02609.ms.pdf
# Paper 065: 065.1-s2.0-S0378775321009617-main.pdf
# Paper 066: 066.PhysRevLett.127.237402.pdf
# Paper 067: 067.1-s2.0-S2666386421004537-main.pdf
# Paper 068: 068.acsenergylett.1c02723.pdf
# Paper 069: 069.d1ee03422g.pdf
# Paper 070: 070.acs.nanolett.2c00047.pdf
# Paper 071: 071.acs.jpclett.2c00770.pdf
# Paper 072: 072.pnas.2200392119.pdf
# Paper 073: 073.acsnano.2c04595.pdf
# Paper 074: 074.acs.chemmater.2c00292.pdf
# Paper 075: 075.acs.jpclett.2c01020.pdf
# Paper 076: 076.PhysRevApplied.18.054031.pdf
# Paper 077: 077.acsanm.2c05257.pdf
# Paper 078: 078.d2nr05732h.ms.pdf
# Paper 079: 079.acs.jpcb.2c08843.ms.pdf
# Paper 080: 080.acs.jpclett.2c03942.pdf
# Paper 081: 081.s41467-023-37857-3.pdf
# Paper 082: 082.s41563-023-01535-y.pdf
# Paper 083: 083.acs.nanolett.3c01825.ms.pdf
# Paper 084: 084.acsami.3c09627.pdf
# Paper 085: 085.acsami.3c07224.ms.pdf
# Paper 086: 086.pnas.2310714120.ms.pdf
# Paper 087: 087.jacs.3c05093.ms.pdf
# Paper 088: 088.anie202316786-ms.pdf
# Sup versions of papers:
# Paper 006: 006.BioChem.bi901283p_Sm.pdf
# Paper 007: 007.cphc_201000528_sm_miscellaneous_information.pdf
# Paper 008: 008.JChemPhys_133_134114_SM.pdf
# Paper 009: 009.jbc-37753-61_SM.pdf
# Paper 011: 011.c0cp01549k_SM.pdf
# Paper 012: 012.jz200453u_si_001.pdf
# Paper 013: 013.nl104227t_si_002.pdf
# Paper 015: 015.jz200760n_si_001.pdf
# Paper 016: 016.pnas.1108073108_SI.pdf
# Paper 017: 017.jp209541e_si_001.pdf
# Paper 018: 018.jz201612y_si_001.pdf
# Paper 019: 019.jz3000036_si_001.pdf
# Paper 020: 020.jp301610b_si_001.pdf
# Paper 021: 021.jp306473u_si_001.pdf
# Paper 024: 024.jp310422q_si_001.pdf
# Paper 027: 027.jz500260s_si.pdf
# Paper 029: 029.jp410861h_si_001.pdf
# Paper 030: 030.science.831.SM.pdf
# Paper 032: 032.nature14327-s1.pdf
# Paper 034: 034.c5cp02951a.SM.pdf
# Paper 035: 035.nl5b02078_si_001.pdf
# Paper 036: 036.c6cp03940e1_si.pdf
# Paper 037: 037.jp6b04264_si_001.pdf
# Paper 039: 039.c6cp06889h1_si.pdf
# Paper 040: 040.nlE7b00249_si.pdf
# Paper 041: 041.acs.jp7b05153_si_001.pdf
# Paper 042: 042.s41467-017-02410-6-SI.pdf
# Paper 043: 043.PhysRevLett.120.023901-SI.pdf
# Paper 044: 044.ja7b11891_si_001.pdf
# Paper 045: 045.ma7b02573_si_001.pdf
# Paper 046: 046.J. Electrochem. Soc.-2018-Wang-A3487-95-SI.pdf
# Paper 048: 048.ja8b09743_si_001.pdf
# Paper 049: 049.acs.langmuir.8b03528_si_001.pdf
# Paper 050: 050.1.5109468-sm.pdf
# Paper 051: 051.jz9b01835_si_001.pdf
# Paper 053: 053.acsenergylett.0c00643.si.pdf
# Paper 054: 054.1-s2.0-S1369702120303382-mmc1.pdf
# Paper 055: 055.s41560-021-00783-z-SI.pdf
# Paper 056: 056.jcp.5.0047656-si.pdf
# Paper 058: 058.abe2265_SM.pdf
# Paper 059: 059.s41467_2021_23603_MOESM1_ESM.pdf;059.s41467_2021_23603_MOESM5_ESM.pdf
# Paper 060: 060.jcp5.0054314-si.pdf
# Paper 061: 061.nl1c01502_si_001.pdf
# Paper 062: 062.ja1c04272_si_001.pdf
# Paper 063: 063.PhysRevLett.127.096801-si.pdf
# Paper 064: 064.acs.jpclett.1c02609.si.pdf
# Paper 065: 065.1-s2.0-S0378775321009617-si.pdf
# Paper 066: 066.PhysRevLett.127.237402.si.pdf
# Paper 067: 067.1-s2.0-S2666386421004537-mmc1.pdf
# Paper 068: 068.acsenergylett.1c02723_si.pdf
# Paper 069: 069.d1ee03422g.si.pdf
# Paper 070: 070.acs.nanolett.2c00047.si.pdf
# Paper 071: 071.jz2c00770_si_001.pdf
# Paper 072: 072.pnas.2200392119.sapp.pdf
# Paper 073: 073.acsnano.2c04595_si_001.pdf
# Paper 075: 075.jz2c01020_si_002.pdf;075.jz2c01020_si_001.pdf
# Paper 077: 077.an2c05257_si_001.pdf
# Paper 078: 078.d2nr05732h.si.pdf
# Paper 079: 079.acs.jpcb.2c08843.si.pdf
# Paper 080: 080.acs.jpclett.2c03942.si.1.pdf;080.acs.jpclett.2c03942.si.2.pdf
# Paper 081: 081.41467_2023_37857_MOESM1_ESM.pdf
# Paper 082: 082.s41563-023-01535-y_ESM.pdf
# Paper 083: 083.acs.nanolett.3c01825.si.pdf
# Paper 084: 084.acsami.3c09627_si_001.pdf
# Paper 085: 085.acsami.3c07224.si.pdf
# Paper 086: 086.pnas.2310714120.sapp.pdf
# Paper 087: 087.jacs.3c05093.si.pdf
# Paper 088: 088.anie202316786-si.pdf

# %% [markdown]
# # EVERYTHING BELOW HERE IS THE AUTOMATION

# %%
import pdfplumber
import re

def extract_dois_from_pdf(pdf_file_path):
    dois = []
    with pdfplumber.open(pdf_file_path) as pdf:
        for page in pdf.pages:
            text = page.extract_text()
            # Use regex to find DOI patterns
            doi_matches = re.findall(r'\b(10\.\d{4,}(?:\.\d+)*\/[-._;()\/:A-Z0-9]+)\b', text, re.IGNORECASE) 
            for match in doi_matches:
                dois.append(match)
    return dois

# %%
import os
import requests
import sys
import json
import shutil

name_to_account = {
    'Tod A. Pascal': 'Tod',
    'Tod Pascal': 'Tod',
}

def replace_with_dictionary(array, dictionary):
    # Iterate over each string in the array
    for i in range(len(array)):
        # If the string is a key in the dictionary, replace it with the corresponding value
        if array[i] in dictionary:
            array[i] = dictionary[array[i]]
    return array

def fetch_data(doi):
    """Fetch publication data from CrossRef API."""
    url = f"https://api.crossref.org/works/{doi}"
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()['message']
    else:
        print("Failed to fetch data.")
        sys.exit(1)

def create_files(pub_data, dir_name, source_dir, main_file, sup_file1, sup_file2):
    """Create directory and files based on publication data."""
    # Ensure valid filenames
    directory = "out"
    sub_directory = dir_name.replace("/", "_").replace("\\", "_").replace('"', '').replace(':', '_').replace('?', '')
    valid_dir_name = os.path.join(directory, sub_directory)
    os.makedirs(valid_dir_name, exist_ok=True)

    # Extracting and formatting author list to include only first names
    authors_source = [f"{author.get('given', '')} {author.get('family', '')}" for author in pub_data.get('author', [])]
    authors = authors_source.copy()
    authors = replace_with_dictionary(authors, name_to_account)
    authors_md = "\n- ".join([""] + authors)  # Markdown list format
    
    # Format publication date correctly
    pub_date_parts = pub_data.get('published-print', pub_data.get('published-online', {'date-parts': [[0]]}))['date-parts'][0]
    if len(pub_date_parts) == 3:  # Full date available
        formatted_pub_date = f"{pub_date_parts[0]:04d}-{pub_date_parts[1]:02d}-{pub_date_parts[2]:02d}T00:00:00Z"
    elif len(pub_date_parts) == 2:  # Only year and month available
        formatted_pub_date = f"{pub_date_parts[0]:04d}-{pub_date_parts[1]:02d}-01T00:00:00Z"
    else:  # Only year available
        formatted_pub_date = f"{pub_date_parts[0]:04d}-01-01T00:00:00Z"

    main_link = ""
    if main_file:
        shutil.copy2(os.path.join(source_dir, main_file), valid_dir_name)
        main_link = f"""- name: Main Paper
  url: "publication/{sub_directory}/{main_file}" """
    sup_link1 = ""
    if sup_file1:
        shutil.copy2(os.path.join(source_dir, sup_file1), valid_dir_name)
        sup_link1 = f"""- name: Supporting Material
  url: "publication/{sub_directory}/{sup_file1}" """
    sup_link2 = ""
    if sup_file2:
        shutil.copy2(os.path.join(source_dir, sup_file2), valid_dir_name)
        sup_link2 = f"""- name: Supporting Material 2
  url: "publication/{sub_directory}/{sup_file2}" """
    
    # Edge Case during parsing:
    publication = pub_data.get('container-title', [''])
    if len(publication) == 0:
        publication = ['']
    # Index.md content
    index_content = f"""---
title: "{pub_data.get('title', [''])[0]}"
authors:{authors_md}
date: "{formatted_pub_date}"
doi: "{pub_data.get('DOI', '')}"
abstract: "{pub_data.get('abstract', '').replace('\n', ' ')}"
links:
{main_link}
{sup_link1}
{sup_link2}
publication: "{publication[0]}"
publication_types: ["article-journal"]
---

Add the publication's full text or supplementary notes here.
"""
    with open(os.path.join(valid_dir_name, "index.md"), "w", encoding='utf-8') as f:
        f.write(index_content)

    # Prepare full names for citation
    bib_authors = ", ".join(authors_source)
    bib_content = f"""@article{{{pub_data.get('DOI', '').replace('/', '_')},
  title = {{{pub_data.get('title', [''])[0]}}},
  author= {{{bib_authors}}},
  journal = {{{publication[0]}}},
  year    = {pub_date_parts[0]},
  volume  = {pub_data.get('volume', '')},
  number  = {pub_data.get('issue', '')},
  doi     = {{{pub_data.get('DOI', '')}}},
  url     = {{{pub_data.get('URL', '')}}}
}}
"""
    with open(os.path.join(valid_dir_name, "cite.bib"), "w", encoding='utf-8') as f:
        f.write(bib_content)

    print(f"Files generated in directory: {valid_dir_name}")

# %%
from collections import Counter

def most_common_string(strings):
    # Count occurrences of each string
    counts = Counter(strings)
    # Find the most common string
    most_common = max(counts, key=counts.get)
    return most_common

# %%
import os

def create_files_with_main_and_supplementary_versions(directory):
    main_versions = {}
    supplementary_versions = {}
    for paper_number in range(1, 89):  # Loop from 1 to 88
        padded_number = str(paper_number).zfill(3)  # Zero-pad the number to ensure three digits
        main_file = None
        sup_file1 = None
        sup_file2 = None
        count = 0
        for filename in os.listdir(directory):
            if filename.startswith(padded_number) and filename.endswith(".pdf"):
                count += 1
                if not any(keyword in filename for keyword in ["_si", "_SM", "-si", "-mmc1", ".sapp", "-s1", ".SM", ".si", "_sm", "_Sm", "_SI", "-SI", "-sm", "_ESM"]):
                    main_file = filename
                    # break  # Found main version, exit loop
                else:
                    if sup_file1:
                        sup_file2 = filename
                    else:
                        sup_file1 = filename
        if main_file:
            main_versions[padded_number] = main_file
        if sup_file1:
            if sup_file2:
                supplementary_versions[padded_number] = sup_file1 + ";" + sup_file2
                if count != 3:
                    raise ValueError(f"File number does not checkout 3 for {padded_number}")
            else:
                supplementary_versions[padded_number] = sup_file1
                if count != 2:
                    raise ValueError(f"File number does not checkout 2 for {padded_number}")
        else:
            if count != 1:
                raise ValueError(f"File number does not checkout 1 for {padded_number}")

        dois = extract_dois_from_pdf(os.path.join(directory, main_file))
        print(dois)
        if len(dois) < 1:
            print(f"No DOI possible for paper {padded_number}")
            continue
        doi = most_common_string(dois)
        pub_data = fetch_data(doi)
        
        # Use title for directory name, or DOI if title is unavailable
        dir_name = pub_data.get('DOI').split('/')[1]
        create_files(pub_data, dir_name, directory, main_file, sup_file1, sup_file2)
        extract_and_mark_figures(os.path.join(directory, main_file), dir_name)
        
    
    return main_versions, supplementary_versions

# %%
import os

def create_files_with_main_and_supplementary_versions_test(directory):
    main_versions = {}
    supplementary_versions = {}
    for paper_number in range(1, 2):  # Loop from 1 to 88
        padded_number = str(paper_number).zfill(3)  # Zero-pad the number to ensure three digits
        main_file = None
        sup_file1 = None
        sup_file2 = None
        count = 0
        for filename in os.listdir(directory):
            if filename.startswith(padded_number) and filename.endswith(".pdf"):
                count += 1
                if not any(keyword in filename for keyword in ["_si", "_SM", "-si", "-mmc1", ".sapp", "-s1", ".SM", ".si", "_sm", "_Sm", "_SI", "-SI", "-sm", "_ESM"]):
                    main_file = filename
                    # break  # Found main version, exit loop
                else:
                    if sup_file1:
                        sup_file2 = filename
                    else:
                        sup_file1 = filename
        if main_file:
            main_versions[padded_number] = main_file
        if sup_file1:
            if sup_file2:
                supplementary_versions[padded_number] = sup_file1 + ";" + sup_file2
                if count != 3:
                    raise ValueError(f"File number does not checkout 3 for {padded_number}")
            else:
                supplementary_versions[padded_number] = sup_file1
                if count != 2:
                    raise ValueError(f"File number does not checkout 2 for {padded_number}")
        else:
            if count != 1:
                raise ValueError(f"File number does not checkout 1 for {padded_number}")

        dois = extract_dois_from_pdf(os.path.join(directory, main_file))
        print(dois)
        if len(dois) < 1:
            print(f"No DOI possible for paper {padded_number}")
            continue
        doi = most_common_string(dois)
        pub_data = fetch_data(doi)
        
        # Use title for directory name, or DOI if title is unavailable
        dir_name = pub_data.get('DOI').split('/')[1]
        create_files(pub_data, dir_name, directory, main_file, sup_file1, sup_file2)
        extract_and_mark_figures(os.path.join(directory, main_file), "test")
    
    return main_versions, supplementary_versions

# %%
# Example usage:
directory = "published"
main_versions, supplementary_versions = create_files_with_main_and_supplementary_versions(directory)
print("Main versions of papers:")
for paper_number, filename in main_versions.items():
    print(f"Paper {paper_number}: {filename}")

print("Sup versions of papers:")
for paper_number, file_path in supplementary_versions.items():
    print(f"Paper {paper_number}: {file_path}")
# Out:
# ['10.1093/nar/gkh931']
# Files generated in directory: out/nar
# Saved figure_1.png from page 2 at nar/figure_1.png
# Saved figure_2.png from page 2 at nar/figure_2.png
# Saved figure_3.jpeg from page 5 at nar/figure_3.jpeg
# Saved figure_4.jpeg from page 5 at nar/figure_4.jpeg
# Saved figure_5.jpeg from page 6 at nar/figure_5.jpeg
# Saved figure_6.jpeg from page 6 at nar/figure_6.jpeg
# Saved figure_7.png from page 6 at nar/figure_7.png
# Saved figure_8.png from page 7 at nar/figure_8.png
# Saved figure_9.png from page 9 at nar/figure_9.png
# Saved figure_10.png from page 9 at nar/figure_10.png
# Saved figure_11.png from page 9 at nar/figure_11.png
# Saved figure_12.png from page 9 at nar/figure_12.png
# ['10.1529/biophysj.105.064733']
# Files generated in directory: out/biophysj.105.064733
# Saved figure_1.png from page 2 at biophysj.105.064733/figure_1.png
# Saved figure_2.jpeg from page 3 at biophysj.105.064733/figure_2.jpeg
# Saved figure_3.jpeg from page 5 at biophysj.105.064733/figure_3.jpeg
# Saved figure_4.jpeg from page 7 at biophysj.105.064733/figure_4.jpeg
# Saved figure_5.jpeg from page 8 at biophysj.105.064733/figure_5.jpeg
# Saved figure_6.jpeg from page 9 at biophysj.105.064733/figure_6.jpeg
# Saved figure_7.jpeg from page 10 at biophysj.105.064733/figure_7.jpeg
# Saved figure_8.jpeg from page 11 at biophysj.105.064733/figure_8.jpeg
# Saved figure_9.jpeg from page 12 at biophysj.105.064733/figure_9.jpeg
# Saved figure_10.jpeg from page 13 at biophysj.105.064733/figure_10.jpeg
# Saved figure_11.jpeg from page 14 at biophysj.105.064733/figure_11.jpeg
# Saved figure_12.jpeg from page 14 at biophysj.105.064733/figure_12.jpeg
# Saved figure_13.png from page 14 at biophysj.105.064733/figure_13.png
# Saved figure_14.jpeg from page 15 at biophysj.105.064733/figure_14.jpeg
# Saved figure_15.jpeg from page 15 at biophysj.105.064733/figure_15.jpeg
# Saved figure_16.jpeg from page 15 at biophysj.105.064733/figure_16.jpeg
# ['10.1166/jnn.2007.704']
# Files generated in directory: out/jnn.2007.704
# Saved figure_1.jpeg from page 2 at jnn.2007.704/figure_1.jpeg
# Saved figure_2.jpeg from page 2 at jnn.2007.704/figure_2.jpeg
# Saved figure_3.jpeg from page 2 at jnn.2007.704/figure_3.jpeg
# Saved figure_4.jpeg from page 2 at jnn.2007.704/figure_4.jpeg
# Saved figure_5.jpeg from page 2 at jnn.2007.704/figure_5.jpeg
# Saved figure_6.jpeg from page 3 at jnn.2007.704/figure_6.jpeg
# Saved figure_7.jpeg from page 3 at jnn.2007.704/figure_7.jpeg
# Saved figure_8.jpeg from page 3 at jnn.2007.704/figure_8.jpeg
# Saved figure_9.jpeg from page 3 at jnn.2007.704/figure_9.jpeg
# Saved figure_10.jpeg from page 3 at jnn.2007.704/figure_10.jpeg
# Saved figure_11.jpeg from page 4 at jnn.2007.704/figure_11.jpeg
# Saved figure_12.jpeg from page 4 at jnn.2007.704/figure_12.jpeg
# Saved figure_13.jpeg from page 4 at jnn.2007.704/figure_13.jpeg
# Saved figure_14.jpeg from page 4 at jnn.2007.704/figure_14.jpeg
# Saved figure_15.jpeg from page 4 at jnn.2007.704/figure_15.jpeg
# Saved figure_16.jpeg from page 4 at jnn.2007.704/figure_16.jpeg
# Saved figure_17.jpeg from page 4 at jnn.2007.704/figure_17.jpeg
# Saved figure_18.jpeg from page 4 at jnn.2007.704/figure_18.jpeg
# Saved figure_19.jpeg from page 4 at jnn.2007.704/figure_19.jpeg
# Saved figure_20.jpeg from page 4 at jnn.2007.704/figure_20.jpeg
# Saved figure_21.jpeg from page 5 at jnn.2007.704/figure_21.jpeg
# Saved figure_22.jpeg from page 5 at jnn.2007.704/figure_22.jpeg
# Saved figure_23.jpeg from page 5 at jnn.2007.704/figure_23.jpeg
# Saved figure_24.jpeg from page 5 at jnn.2007.704/figure_24.jpeg
# Saved figure_25.jpeg from page 6 at jnn.2007.704/figure_25.jpeg
# Saved figure_26.jpeg from page 6 at jnn.2007.704/figure_26.jpeg
# Saved figure_27.jpeg from page 6 at jnn.2007.704/figure_27.jpeg
# Saved figure_28.jpeg from page 7 at jnn.2007.704/figure_28.jpeg
# Saved figure_29.jpeg from page 7 at jnn.2007.704/figure_29.jpeg
# Saved figure_30.jpeg from page 8 at jnn.2007.704/figure_30.jpeg
# Saved figure_31.jpeg from page 8 at jnn.2007.704/figure_31.jpeg
# Saved figure_32.jpeg from page 8 at jnn.2007.704/figure_32.jpeg
# Saved figure_33.jpeg from page 8 at jnn.2007.704/figure_33.jpeg
# []
# No DOI possible for paper 004
# []
# No DOI possible for paper 005
# ['10.1021/bi901283p']
# Files generated in directory: out/bi901283p
# Saved figure_1.png from page 2 at bi901283p/figure_1.png
# Saved figure_2.png from page 2 at bi901283p/figure_2.png
# Saved figure_3.png from page 3 at bi901283p/figure_3.png
# Saved figure_4.png from page 4 at bi901283p/figure_4.png
# Saved figure_5.png from page 5 at bi901283p/figure_5.png
# Saved figure_6.png from page 5 at bi901283p/figure_6.png
# Saved figure_7.png from page 5 at bi901283p/figure_7.png
# Saved figure_8.png from page 6 at bi901283p/figure_8.png
# Saved figure_9.png from page 6 at bi901283p/figure_9.png
# ['10.1002/cphc.201000528', '10.1002/cphc.201000528']
# Files generated in directory: out/cphc.201000528
# Saved figure_1.png from page 1 at cphc.201000528/figure_1.png
# Saved figure_2.jpeg from page 1 at cphc.201000528/figure_2.jpeg
# Saved figure_3.jpeg from page 2 at cphc.201000528/figure_3.jpeg
# Saved figure_4.jpeg from page 3 at cphc.201000528/figure_4.jpeg
# Saved figure_5.jpeg from page 4 at cphc.201000528/figure_5.jpeg
# Saved figure_6.jpeg from page 5 at cphc.201000528/figure_6.jpeg
# ['10.1063/1.3456543', '10.1063/1.3456543', '10.1063/1.3456543(cid:5', '10.1063/1.3456543']
# Files generated in directory: out/1.3456543
# Saved figure_1.png from page 1 at 1.3456543/figure_1.png
# Saved figure_2.jpeg from page 1 at 1.3456543/figure_2.jpeg
# Saved figure_3.png from page 1 at 1.3456543/figure_3.png
# Saved figure_4.png from page 4 at 1.3456543/figure_4.png
# Saved figure_5.png from page 4 at 1.3456543/figure_5.png
# Saved figure_6.png from page 5 at 1.3456543/figure_6.png
# Saved figure_7.jpeg from page 5 at 1.3456543/figure_7.jpeg
# Saved figure_8.jpeg from page 12 at 1.3456543/figure_8.jpeg
# Saved figure_9.png from page 13 at 1.3456543/figure_9.png
# Saved figure_10.jpeg from page 13 at 1.3456543/figure_10.jpeg
# Saved figure_11.jpeg from page 15 at 1.3456543/figure_11.jpeg
# Saved figure_12.jpeg from page 15 at 1.3456543/figure_12.jpeg
# []
# No DOI possible for paper 009
# ['10.1021/jz101391r', '10.1021/jz101391r', '10.1021/jz101391r', '10.1021/jz101391r', '10.1021/jz101391r', '10.1021/jz101391r', '10.1021/jz101391r', '10.1021/jz101391r', '10.1021/jz101391r']
# Files generated in directory: out/jz101391r
# Saved figure_1.png from page 1 at jz101391r/figure_1.png
# Saved figure_2.png from page 2 at jz101391r/figure_2.png
# Saved figure_3.png from page 3 at jz101391r/figure_3.png
# Saved figure_4.png from page 3 at jz101391r/figure_4.png
# Saved figure_5.png from page 4 at jz101391r/figure_5.png
# Saved figure_6.png from page 5 at jz101391r/figure_6.png
# Saved figure_7.png from page 5 at jz101391r/figure_7.png
# Saved figure_8.png from page 6 at jz101391r/figure_8.png
# ['10.1039/c0cp01549k']
# Files generated in directory: out/c0cp01549k
# Saved figure_1.png from page 8 at c0cp01549k/figure_1.png
# Saved figure_2.jpeg from page 9 at c0cp01549k/figure_2.jpeg
# Saved figure_3.jpeg from page 10 at c0cp01549k/figure_3.jpeg
# Saved figure_4.jpeg from page 10 at c0cp01549k/figure_4.jpeg
# Saved figure_5.jpeg from page 11 at c0cp01549k/figure_5.jpeg
# Saved figure_6.jpeg from page 11 at c0cp01549k/figure_6.jpeg
# ['10.1021/jz200453u', '10.1021/jz200453u', '10.1021/jz200453u', '10.1021/jz200453u']
# Files generated in directory: out/jz200453u
# Saved figure_1.png from page 1 at jz200453u/figure_1.png
# Saved figure_2.png from page 2 at jz200453u/figure_2.png
# Saved figure_3.png from page 3 at jz200453u/figure_3.png
# Saved figure_4.png from page 3 at jz200453u/figure_4.png
# ['10.1021/nl104227t', '10.1021/nl104227t', '10.1021/nl104227t', '10.1021/nl104227t', '10.1021/nl104227t', '10.1021/nl104227t']
# Files generated in directory: out/nl104227t
# Saved figure_1.jpeg from page 1 at nl104227t/figure_1.jpeg
# Saved figure_2.jpeg from page 2 at nl104227t/figure_2.jpeg
# Saved figure_3.jpeg from page 3 at nl104227t/figure_3.jpeg
# Saved figure_4.png from page 4 at nl104227t/figure_4.png
# Saved figure_5.png from page 5 at nl104227t/figure_5.png
# ['10.1021/ct200211b', '10.1021/ct200211b', '10.1021/ct200211b', '10.1021/ct200211b', '10.1021/ct200211b', '10.1021/ct200211b', '10.1021/ct200211b', '10.1021/ct200211b', '10.1021/ct200211b']
# Files generated in directory: out/ct200211b
# Saved figure_1.png from page 4 at ct200211b/figure_1.png
# Saved figure_2.png from page 5 at ct200211b/figure_2.png
# Saved figure_3.png from page 5 at ct200211b/figure_3.png
# Saved figure_4.png from page 5 at ct200211b/figure_4.png
# Saved figure_5.png from page 6 at ct200211b/figure_5.png
# Saved figure_6.png from page 6 at ct200211b/figure_6.png
# Saved figure_7.png from page 6 at ct200211b/figure_7.png
# Saved figure_8.png from page 6 at ct200211b/figure_8.png
# Saved figure_9.png from page 7 at ct200211b/figure_9.png
# ['10.1021/jz200760n', '10.1021/jz200760n', '10.1021/jz200760n', '10.1021/jz200760n']
# Files generated in directory: out/jz200760n
# Saved figure_1.png from page 1 at jz200760n/figure_1.png
# Saved figure_2.png from page 2 at jz200760n/figure_2.png
# Saved figure_3.png from page 2 at jz200760n/figure_3.png
# Saved figure_4.png from page 2 at jz200760n/figure_4.png
# Saved figure_5.png from page 3 at jz200760n/figure_5.png
# ['10.1073/pnas.1108073108/-/DCSupplemental', '10.1073/pnas.1108073108', '10.1073/pnas.1108073108', '10.1073/pnas.1108073108']
# Files generated in directory: out/pnas.1108073108
# Saved figure_1.jpeg from page 1 at pnas.1108073108/figure_1.jpeg
# Saved figure_2.jpeg from page 2 at pnas.1108073108/figure_2.jpeg
# Saved figure_3.jpeg from page 2 at pnas.1108073108/figure_3.jpeg
# Saved figure_4.jpeg from page 2 at pnas.1108073108/figure_4.jpeg
# Saved figure_5.jpeg from page 3 at pnas.1108073108/figure_5.jpeg
# Saved figure_6.jpeg from page 3 at pnas.1108073108/figure_6.jpeg
# Saved figure_7.jpeg from page 3 at pnas.1108073108/figure_7.jpeg
# Saved figure_8.jpeg from page 4 at pnas.1108073108/figure_8.jpeg
# Saved figure_9.jpeg from page 5 at pnas.1108073108/figure_9.jpeg
# ['10.1021/jp209541e', '10.1021/jp209541e', '10.1021/jp209541e', '10.1021/jp209541e', '10.1021/jp209541e', '10.1021/jp209541e']
# Files generated in directory: out/jp209541e
# Saved figure_1.png from page 1 at jp209541e/figure_1.png
# Saved figure_2.png from page 2 at jp209541e/figure_2.png
# Saved figure_3.png from page 2 at jp209541e/figure_3.png
# Saved figure_4.png from page 3 at jp209541e/figure_4.png
# Saved figure_5.png from page 4 at jp209541e/figure_5.png
# Saved figure_6.png from page 4 at jp209541e/figure_6.png
# ['10.1021/jz201612y', '10.1021/jz201612y', '10.1021/jz201612y', '10.1021/jz201612y', '10.1021/jz201612y']
# Files generated in directory: out/jz201612y
# Saved figure_1.png from page 1 at jz201612y/figure_1.png
# Saved figure_2.png from page 2 at jz201612y/figure_2.png
# Saved figure_3.png from page 3 at jz201612y/figure_3.png
# Saved figure_4.png from page 3 at jz201612y/figure_4.png
# Saved figure_5.png from page 3 at jz201612y/figure_5.png
# Saved figure_6.png from page 4 at jz201612y/figure_6.png
# ['10.1021/jz3000036', '10.1021/jz3000036', '10.1021/jz3000036', '10.1021/jz3000036']
# Files generated in directory: out/jz3000036
# Saved figure_1.png from page 1 at jz3000036/figure_1.png
# Saved figure_2.png from page 2 at jz3000036/figure_2.png
# Saved figure_3.png from page 2 at jz3000036/figure_3.png
# Saved figure_4.png from page 3 at jz3000036/figure_4.png
# Saved figure_5.png from page 3 at jz3000036/figure_5.png
# ['10.1021/jp301610b', '10.1021/jp301610b', '10.1021/jp301610b', '10.1021/jp301610b', '10.1021/jp301610b', '10.1021/jp301610b', '10.1021/jp301610b', '10.1021/jp301610b', '10.1021/jp301610b', '10.1021/jp301610b', '10.1021/jp301610b', '10.1021/jp301610b']
# Files generated in directory: out/jp301610b
# Saved figure_1.jpeg from page 1 at jp301610b/figure_1.jpeg
# Saved figure_2.jpeg from page 2 at jp301610b/figure_2.jpeg
# Saved figure_3.jpeg from page 3 at jp301610b/figure_3.jpeg
# Saved figure_4.jpeg from page 4 at jp301610b/figure_4.jpeg
# Saved figure_5.jpeg from page 5 at jp301610b/figure_5.jpeg
# Saved figure_6.jpeg from page 6 at jp301610b/figure_6.jpeg
# Saved figure_7.jpeg from page 7 at jp301610b/figure_7.jpeg
# Saved figure_8.jpeg from page 7 at jp301610b/figure_8.jpeg
# Saved figure_9.jpeg from page 8 at jp301610b/figure_9.jpeg
# Saved figure_10.jpeg from page 9 at jp301610b/figure_10.jpeg
# Saved figure_11.jpeg from page 10 at jp301610b/figure_11.jpeg
# Saved figure_12.png from page 10 at jp301610b/figure_12.png
# Saved figure_13.jpeg from page 10 at jp301610b/figure_13.jpeg
# ['10.1021/jp306473u', '10.1021/jp306473u', '10.1021/jp306473u', '10.1021/jp306473u', '10.1021/jp306473u', '10.1021/jp306473u', '10.1021/jp306473u', '10.1021/jp306473u', '10.1021/jp306473u']
# Files generated in directory: out/jp306473u
# Saved figure_1.jpeg from page 1 at jp306473u/figure_1.jpeg
# Saved figure_2.jpeg from page 2 at jp306473u/figure_2.jpeg
# Saved figure_3.jpeg from page 3 at jp306473u/figure_3.jpeg
# Saved figure_4.jpeg from page 4 at jp306473u/figure_4.jpeg
# Saved figure_5.jpeg from page 4 at jp306473u/figure_5.jpeg
# Saved figure_6.jpeg from page 4 at jp306473u/figure_6.jpeg
# Saved figure_7.jpeg from page 5 at jp306473u/figure_7.jpeg
# Saved figure_8.jpeg from page 6 at jp306473u/figure_8.jpeg
# Saved figure_9.jpeg from page 6 at jp306473u/figure_9.jpeg
# ['10.1021/jp309693d', '10.1021/jp309693d', '10.1021/jp309693d', '10.1021/jp309693d', '10.1021/jp309693d', '10.1021/jp309693d', '10.1021/jp309693d', '10.1021/jp309693d']
# Files generated in directory: out/jp309693d
# Saved figure_1.png from page 1 at jp309693d/figure_1.png
# Saved figure_2.png from page 3 at jp309693d/figure_2.png
# Saved figure_3.png from page 4 at jp309693d/figure_3.png
# Saved figure_4.png from page 5 at jp309693d/figure_4.png
# Saved figure_5.png from page 7 at jp309693d/figure_5.png
# ['10.1063/1.4771974']
# Files generated in directory: out/1.4771974
# Saved figure_1.jpeg from page 1 at 1.4771974/figure_1.jpeg
# Saved figure_2.jpeg from page 4 at 1.4771974/figure_2.jpeg
# Saved figure_3.jpeg from page 4 at 1.4771974/figure_3.jpeg
# ['10.1021/jp310422q', '10.1021/jp310422q', '10.1021/jp310422q', '10.1021/jp310422q', '10.1021/jp310422q', '10.1021/jp310422q', '10.1021/jp310422q', '10.1021/jp310422q', '10.1021/jp310422q', '10.1021/jp310422q', '10.1021/jp310422q', '10.1021/jp310422q']
# Files generated in directory: out/jp310422q
# Saved figure_1.jpeg from page 1 at jp310422q/figure_1.jpeg
# Saved figure_2.png from page 2 at jp310422q/figure_2.png
# Saved figure_3.jpeg from page 2 at jp310422q/figure_3.jpeg
# Saved figure_4.jpeg from page 3 at jp310422q/figure_4.jpeg
# Saved figure_5.jpeg from page 4 at jp310422q/figure_5.jpeg
# Saved figure_6.jpeg from page 5 at jp310422q/figure_6.jpeg
# Saved figure_7.jpeg from page 5 at jp310422q/figure_7.jpeg
# Saved figure_8.jpeg from page 6 at jp310422q/figure_8.jpeg
# Saved figure_9.jpeg from page 6 at jp310422q/figure_9.jpeg
# Saved figure_10.jpeg from page 7 at jp310422q/figure_10.jpeg
# Saved figure_11.jpeg from page 8 at jp310422q/figure_11.jpeg
# Saved figure_12.jpeg from page 9 at jp310422q/figure_12.jpeg
# Saved figure_13.jpeg from page 10 at jp310422q/figure_13.jpeg
# ['10.1016/j.commatsci.2012.12.024']
# Files generated in directory: out/j.commatsci.2012.12.024
# Saved figure_1.jpeg from page 1 at j.commatsci.2012.12.024/figure_1.jpeg
# Saved figure_2.jpeg from page 1 at j.commatsci.2012.12.024/figure_2.jpeg
# Saved figure_3.jpeg from page 2 at j.commatsci.2012.12.024/figure_3.jpeg
# Saved figure_4.jpeg from page 2 at j.commatsci.2012.12.024/figure_4.jpeg
# Saved figure_5.jpeg from page 2 at j.commatsci.2012.12.024/figure_5.jpeg
# Saved figure_6.jpeg from page 3 at j.commatsci.2012.12.024/figure_6.jpeg
# Saved figure_7.jpeg from page 3 at j.commatsci.2012.12.024/figure_7.jpeg
# Saved figure_8.jpeg from page 4 at j.commatsci.2012.12.024/figure_8.jpeg
# Saved figure_9.jpeg from page 5 at j.commatsci.2012.12.024/figure_9.jpeg
# Saved figure_10.jpeg from page 5 at j.commatsci.2012.12.024/figure_10.jpeg
# Saved figure_11.jpeg from page 6 at j.commatsci.2012.12.024/figure_11.jpeg
# ['10.1063/1.4856835']
# Files generated in directory: out/1.4856835
# Saved figure_1.jpeg from page 1 at 1.4856835/figure_1.jpeg
# Saved figure_2.jpeg from page 5 at 1.4856835/figure_2.jpeg
# Saved figure_3.jpeg from page 7 at 1.4856835/figure_3.jpeg
# Saved figure_4.jpeg from page 8 at 1.4856835/figure_4.jpeg
# Saved figure_5.jpeg from page 9 at 1.4856835/figure_5.jpeg
# Saved figure_6.jpeg from page 9 at 1.4856835/figure_6.jpeg
# Saved figure_7.jpeg from page 10 at 1.4856835/figure_7.jpeg
# Saved figure_8.jpeg from page 10 at 1.4856835/figure_8.jpeg
# Saved figure_9.jpeg from page 11 at 1.4856835/figure_9.jpeg
# Saved figure_10.jpeg from page 11 at 1.4856835/figure_10.jpeg
# ['10.1021/jz500260s', '10.1021/jz500260s', '10.1021/jz500260s', '10.1021/jz500260s', '10.1021/jz500260s']
# Files generated in directory: out/jz500260s
# Saved figure_1.png from page 1 at jz500260s/figure_1.png
# Saved figure_2.png from page 2 at jz500260s/figure_2.png
# Saved figure_3.png from page 3 at jz500260s/figure_3.png
# Saved figure_4.png from page 4 at jz500260s/figure_4.png
# ['10.1149/2.078406jes']
# Files generated in directory: out/2.078406jes
# Saved figure_1.jpeg from page 1 at 2.078406jes/figure_1.jpeg
# Saved figure_2.jpeg from page 3 at 2.078406jes/figure_2.jpeg
# Saved figure_3.jpeg from page 3 at 2.078406jes/figure_3.jpeg
# Saved figure_4.jpeg from page 4 at 2.078406jes/figure_4.jpeg
# Saved figure_5.jpeg from page 4 at 2.078406jes/figure_5.jpeg
# Saved figure_6.jpeg from page 5 at 2.078406jes/figure_6.jpeg
# Saved figure_7.jpeg from page 6 at 2.078406jes/figure_7.jpeg
# ['10.1021/jp410861h', '10.1021/jp410861h', '10.1021/jp410861h', '10.1021/jp410861h', '10.1021/jp410861h', '10.1021/jp410861h', '10.1021/jp410861h', '10.1021/jp410861h', '10.1021/jp410861h', '10.1021/jp410861h', '10.1021/jp410861h', '10.1073/pnas.1200949109', '10.1021/jp410861h', '10.1021/jp410861h', '10.1021/jp410861h']
# Files generated in directory: out/jp410861h
# Saved figure_1.png from page 1 at jp410861h/figure_1.png
# Saved figure_2.png from page 3 at jp410861h/figure_2.png
# Saved figure_3.png from page 7 at jp410861h/figure_3.png
# Saved figure_4.png from page 7 at jp410861h/figure_4.png
# Saved figure_5.png from page 8 at jp410861h/figure_5.png
# Saved figure_6.png from page 8 at jp410861h/figure_6.png
# Saved figure_7.png from page 10 at jp410861h/figure_7.png
# Saved figure_8.png from page 10 at jp410861h/figure_8.png
# Saved figure_9.png from page 11 at jp410861h/figure_9.png
# ['10.1126/science.1259437', '10.1126/science.1258405', '10.1126/science.1259437']
# Files generated in directory: out/science.1259437
# Saved figure_1.png from page 1 at science.1259437/figure_1.png
# Saved figure_2.png from page 2 at science.1259437/figure_2.png
# Saved figure_3.png from page 2 at science.1259437/figure_3.png
# Saved figure_4.png from page 2 at science.1259437/figure_4.png
# Saved figure_5.png from page 2 at science.1259437/figure_5.png
# Saved figure_6.png from page 3 at science.1259437/figure_6.png
# Saved figure_7.png from page 3 at science.1259437/figure_7.png
# Saved figure_8.jpeg from page 3 at science.1259437/figure_8.jpeg
# Saved figure_9.jpeg from page 3 at science.1259437/figure_9.jpeg
# Saved figure_10.png from page 4 at science.1259437/figure_10.png
# Saved figure_11.png from page 4 at science.1259437/figure_11.png
# Saved figure_12.jpeg from page 4 at science.1259437/figure_12.jpeg
# Saved figure_13.jpeg from page 4 at science.1259437/figure_13.jpeg
# Saved figure_14.png from page 5 at science.1259437/figure_14.png
# Saved figure_15.png from page 5 at science.1259437/figure_15.png
# Saved figure_16.png from page 5 at science.1259437/figure_16.png
# Saved figure_17.png from page 5 at science.1259437/figure_17.png
# ['10.1039/c4cp05316h', '10.1002/aenm.201401801']
# Files generated in directory: out/c4cp05316h
# Saved figure_1.jpeg from page 1 at c4cp05316h/figure_1.jpeg
# Saved figure_2.jpeg from page 3 at c4cp05316h/figure_2.jpeg
# Saved figure_3.png from page 4 at c4cp05316h/figure_3.png
# Saved figure_4.jpeg from page 4 at c4cp05316h/figure_4.jpeg
# Saved figure_5.jpeg from page 5 at c4cp05316h/figure_5.jpeg
# Saved figure_6.jpeg from page 5 at c4cp05316h/figure_6.jpeg
# Saved figure_7.jpeg from page 6 at c4cp05316h/figure_7.jpeg
# Saved figure_8.jpeg from page 6 at c4cp05316h/figure_8.jpeg
# Saved figure_9.jpeg from page 7 at c4cp05316h/figure_9.jpeg
# Saved figure_10.jpeg from page 7 at c4cp05316h/figure_10.jpeg
# Saved figure_11.jpeg from page 8 at c4cp05316h/figure_11.jpeg
# Saved figure_12.jpeg from page 9 at c4cp05316h/figure_12.jpeg
# ['10.1038/nature14327']
# Files generated in directory: out/nature14327
# Saved figure_1.png from page 3 at nature14327/figure_1.png
# Saved figure_2.jpeg from page 3 at nature14327/figure_2.jpeg
# Saved figure_3.jpeg from page 3 at nature14327/figure_3.jpeg
# Saved figure_4.png from page 3 at nature14327/figure_4.png
# Saved figure_5.jpeg from page 3 at nature14327/figure_5.jpeg
# Saved figure_6.png from page 3 at nature14327/figure_6.png
# Saved figure_7.jpeg from page 3 at nature14327/figure_7.jpeg
# Saved figure_8.png from page 10 at nature14327/figure_8.png
# Saved figure_9.png from page 11 at nature14327/figure_9.png
# Saved figure_10.jpeg from page 12 at nature14327/figure_10.jpeg
# Saved figure_11.png from page 13 at nature14327/figure_11.png
# Saved figure_12.png from page 14 at nature14327/figure_12.png
# Saved figure_13.png from page 15 at nature14327/figure_13.png
# Saved figure_14.png from page 16 at nature14327/figure_14.png
# ['10.1002/aenm.201500285', '10.1002/aenm.201401801']
# Files generated in directory: out/aenm.201500285
# Saved figure_1.png from page 1 at aenm.201500285/figure_1.png
# Saved figure_2.png from page 1 at aenm.201500285/figure_2.png
# Saved figure_3.png from page 1 at aenm.201500285/figure_3.png
# Saved figure_4.png from page 2 at aenm.201500285/figure_4.png
# Saved figure_5.png from page 2 at aenm.201500285/figure_5.png
# Saved figure_6.png from page 3 at aenm.201500285/figure_6.png
# Saved figure_7.png from page 3 at aenm.201500285/figure_7.png
# Saved figure_8.jpeg from page 3 at aenm.201500285/figure_8.jpeg
# Saved figure_9.png from page 4 at aenm.201500285/figure_9.png
# Saved figure_10.png from page 4 at aenm.201500285/figure_10.png
# Saved figure_11.jpeg from page 4 at aenm.201500285/figure_11.jpeg
# Saved figure_12.png from page 5 at aenm.201500285/figure_12.png
# Saved figure_13.png from page 5 at aenm.201500285/figure_13.png
# Saved figure_14.jpeg from page 5 at aenm.201500285/figure_14.jpeg
# Saved figure_15.png from page 6 at aenm.201500285/figure_15.png
# Saved figure_16.png from page 6 at aenm.201500285/figure_16.png
# Saved figure_17.jpeg from page 6 at aenm.201500285/figure_17.jpeg
# Saved figure_18.jpeg from page 7 at aenm.201500285/figure_18.jpeg
# Saved figure_19.png from page 7 at aenm.201500285/figure_19.png
# Saved figure_20.png from page 7 at aenm.201500285/figure_20.png
# Saved figure_21.png from page 8 at aenm.201500285/figure_21.png
# Saved figure_22.png from page 8 at aenm.201500285/figure_22.png
# Saved figure_23.png from page 9 at aenm.201500285/figure_23.png
# Saved figure_24.png from page 9 at aenm.201500285/figure_24.png
# Saved figure_25.png from page 10 at aenm.201500285/figure_25.png
# Saved figure_26.png from page 10 at aenm.201500285/figure_26.png
# ['10.1039/c5cp02951a', '10.1039/c5cp02951a', '10.1039/c5cp02951a', '10.1039/C5SC01828E']
# Files generated in directory: out/c5cp02951a
# Saved figure_1.jpeg from page 1 at c5cp02951a/figure_1.jpeg
# Saved figure_2.png from page 4 at c5cp02951a/figure_2.png
# Saved figure_3.jpeg from page 5 at c5cp02951a/figure_3.jpeg
# Saved figure_4.jpeg from page 6 at c5cp02951a/figure_4.jpeg
# Saved figure_5.jpeg from page 7 at c5cp02951a/figure_5.jpeg
# Saved figure_6.jpeg from page 8 at c5cp02951a/figure_6.jpeg
# ['10.1021/acs.nanolett.5b02078', '10.1021/acs.nanolett.5b02078', '10.1021/acs.nanolett.5b02078', '10.1021/acs.nano', '10.1021/acs.nanolett.5b02078', '10.1021/acs.nanolett.5b02078', '10.1021/acs.nanolett.5b02078']
# Files generated in directory: out/acs.nanolett.5b02078
# Saved figure_1.png from page 1 at acs.nanolett.5b02078/figure_1.png
# Saved figure_2.png from page 2 at acs.nanolett.5b02078/figure_2.png
# Saved figure_3.png from page 2 at acs.nanolett.5b02078/figure_3.png
# Saved figure_4.png from page 3 at acs.nanolett.5b02078/figure_4.png
# Saved figure_5.png from page 4 at acs.nanolett.5b02078/figure_5.png
# ['10.1039/c6cp03940e', '10.1039/c6cp03940e']
# Files generated in directory: out/c6cp03940e
# Saved figure_1.jpeg from page 1 at c6cp03940e/figure_1.jpeg
# Saved figure_2.jpeg from page 2 at c6cp03940e/figure_2.jpeg
# Saved figure_3.jpeg from page 3 at c6cp03940e/figure_3.jpeg
# Saved figure_4.jpeg from page 4 at c6cp03940e/figure_4.jpeg
# Saved figure_5.jpeg from page 4 at c6cp03940e/figure_5.jpeg
# Saved figure_6.jpeg from page 5 at c6cp03940e/figure_6.jpeg
# ['10.1021/acs.jpcc.6b04264', '10.1021/acs.jpcc.6b04264', '10.1021/acs.jpcc.6b04264', '10.1021/acs.jpcc.6b04264', '10.1021/acs.jpcc.6b04264', '10.1021/acs.jpcc.6b04264', '10.1021/acs.jpcc.6b04264', '10.1021/acs.jpcc.6b04264', '10.1021/acs.jpcc.6b04264']
# Files generated in directory: out/acs.jpcc.6b04264
# Saved figure_1.png from page 1 at acs.jpcc.6b04264/figure_1.png
# Saved figure_2.png from page 3 at acs.jpcc.6b04264/figure_2.png
# Saved figure_3.png from page 3 at acs.jpcc.6b04264/figure_3.png
# Saved figure_4.png from page 3 at acs.jpcc.6b04264/figure_4.png
# Saved figure_5.png from page 4 at acs.jpcc.6b04264/figure_5.png
# Saved figure_6.png from page 4 at acs.jpcc.6b04264/figure_6.png
# Saved figure_7.png from page 5 at acs.jpcc.6b04264/figure_7.png
# Saved figure_8.png from page 5 at acs.jpcc.6b04264/figure_8.png
# Saved figure_9.png from page 6 at acs.jpcc.6b04264/figure_9.png
# Saved figure_10.png from page 6 at acs.jpcc.6b04264/figure_10.png
# ['10.1149/2.1441614jes']
# Files generated in directory: out/2.1441614jes
# Saved figure_1.png from page 1 at 2.1441614jes/figure_1.png
# Saved figure_2.jpeg from page 2 at 2.1441614jes/figure_2.jpeg
# Saved figure_3.jpeg from page 3 at 2.1441614jes/figure_3.jpeg
# Saved figure_4.jpeg from page 3 at 2.1441614jes/figure_4.jpeg
# Saved figure_5.jpeg from page 4 at 2.1441614jes/figure_5.jpeg
# Saved figure_6.jpeg from page 4 at 2.1441614jes/figure_6.jpeg
# Saved figure_7.jpeg from page 5 at 2.1441614jes/figure_7.jpeg
# Saved figure_8.jpeg from page 5 at 2.1441614jes/figure_8.jpeg
# Saved figure_9.jpeg from page 6 at 2.1441614jes/figure_9.jpeg
# Saved figure_10.jpeg from page 6 at 2.1441614jes/figure_10.jpeg
# Saved figure_11.jpeg from page 7 at 2.1441614jes/figure_11.jpeg
# Saved figure_12.jpeg from page 7 at 2.1441614jes/figure_12.jpeg
# Saved figure_13.jpeg from page 8 at 2.1441614jes/figure_13.jpeg
# Saved figure_14.jpeg from page 8 at 2.1441614jes/figure_14.jpeg
# ['10.1039/c6cp06889h', '10.1039/c6cp06889h']
# Files generated in directory: out/c6cp06889h
# Saved figure_1.jpeg from page 1 at c6cp06889h/figure_1.jpeg
# Saved figure_2.jpeg from page 4 at c6cp06889h/figure_2.jpeg
# Saved figure_3.jpeg from page 5 at c6cp06889h/figure_3.jpeg
# Saved figure_4.jpeg from page 6 at c6cp06889h/figure_4.jpeg
# Saved figure_5.jpeg from page 7 at c6cp06889h/figure_5.jpeg
# ['10.1021/acs.nanolett.7b00249', '10.1021/acs.nanolett.7b00249', '10.1021/acs.nanolett.7b00249', '10.1021/acs.nanolett.7b00249', '10.1021/acs.nanolett.7b00249', '10.1021/acs.nano', '10.1021/acs.nanolett.7b00249', '10.1021/acs.nanolett.7b00249']
# Files generated in directory: out/acs.nanolett.7b00249
# Saved figure_1.png from page 1 at acs.nanolett.7b00249/figure_1.png
# Saved figure_2.png from page 2 at acs.nanolett.7b00249/figure_2.png
# Saved figure_3.png from page 3 at acs.nanolett.7b00249/figure_3.png
# Saved figure_4.png from page 4 at acs.nanolett.7b00249/figure_4.png
# Saved figure_5.png from page 5 at acs.nanolett.7b00249/figure_5.png
# ['10.1021/acs.jpcc.7b05153', '10.1021/acs.jpcc.7b05153', '10.1021/acs.jpcc.7b05153', '10.1021/acs.jpcc.7b05153', '10.1021/acs.jpcc.7b05153', '10.1021/acs.jpcc.7b05153', '10.1021/acs.jpcc.7b05153', '10.1021/acs.jpcc.7b05153', '10.1021/acs.jpcc.7b05153']
# Files generated in directory: out/acs.jpcc.7b05153
# Saved figure_1.png from page 1 at acs.jpcc.7b05153/figure_1.png
# Saved figure_2.png from page 2 at acs.jpcc.7b05153/figure_2.png
# Saved figure_3.png from page 3 at acs.jpcc.7b05153/figure_3.png
# Saved figure_4.png from page 4 at acs.jpcc.7b05153/figure_4.png
# Saved figure_5.png from page 4 at acs.jpcc.7b05153/figure_5.png
# Saved figure_6.png from page 6 at acs.jpcc.7b05153/figure_6.png
# ['10.1038/s41467-017-02410-6', '10.1038/s41467-017-02410-6', '10.1038/s41467-017-02410-6', '10.1038/s41467-017-02410-6', '10.1038/s41467-017-02410-6', '10.1038/s41467-017-02410-6', '10.1038/s41467-017-02410-6', '10.1038/s41467-017-02410-6', '10.1038/s41467-017-02410-6', '10.1038/s41467-017-02410-6', '10.1038/s41467-017-02410-6', '10.1038/s41467-017-02410-6', '10.1038/s41467-017-02410-6', '10.1038/s41467-017-02410-6', '10.1038/s41467-017-02410-6', '10.1038/s41467-017-02410-6', '10.1038/s41467-017-02410-6', '10.1038/s41467-017-02410-6', '10.1038/s41467-017-02410-6', '10.1038/s41467', '10.1038/s41467-017-02410-6']
# Files generated in directory: out/s41467-017-02410-6
# Saved figure_1.jpeg from page 2 at s41467-017-02410-6/figure_1.jpeg
# Saved figure_2.jpeg from page 2 at s41467-017-02410-6/figure_2.jpeg
# Saved figure_3.png from page 3 at s41467-017-02410-6/figure_3.png
# Saved figure_4.png from page 3 at s41467-017-02410-6/figure_4.png
# Saved figure_5.png from page 3 at s41467-017-02410-6/figure_5.png
# Saved figure_6.png from page 3 at s41467-017-02410-6/figure_6.png
# Saved figure_7.png from page 3 at s41467-017-02410-6/figure_7.png
# Saved figure_8.png from page 3 at s41467-017-02410-6/figure_8.png
# Saved figure_9.jpeg from page 5 at s41467-017-02410-6/figure_9.jpeg
# Saved figure_10.png from page 5 at s41467-017-02410-6/figure_10.png
# Saved figure_11.jpeg from page 5 at s41467-017-02410-6/figure_11.jpeg
# Saved figure_12.jpeg from page 5 at s41467-017-02410-6/figure_12.jpeg
# Saved figure_13.jpeg from page 5 at s41467-017-02410-6/figure_13.jpeg
# Saved figure_14.jpeg from page 5 at s41467-017-02410-6/figure_14.jpeg
# Saved figure_15.png from page 6 at s41467-017-02410-6/figure_15.png
# Saved figure_16.png from page 6 at s41467-017-02410-6/figure_16.png
# Saved figure_17.png from page 6 at s41467-017-02410-6/figure_17.png
# Saved figure_18.png from page 6 at s41467-017-02410-6/figure_18.png
# Saved figure_19.png from page 6 at s41467-017-02410-6/figure_19.png
# Saved figure_20.png from page 7 at s41467-017-02410-6/figure_20.png
# Saved figure_21.png from page 7 at s41467-017-02410-6/figure_21.png
# Saved figure_22.png from page 7 at s41467-017-02410-6/figure_22.png
# Saved figure_23.png from page 7 at s41467-017-02410-6/figure_23.png
# Saved figure_24.png from page 9 at s41467-017-02410-6/figure_24.png
# ['10.1103/PhysRevLett.120.023901', '10.1103/PhysRevLett.120.023901']
# Files generated in directory: out/physrevlett.120.023901
# Saved figure_1.png from page 2 at physrevlett.120.023901/figure_1.png
# Saved figure_2.jpeg from page 2 at physrevlett.120.023901/figure_2.jpeg
# Saved figure_3.jpeg from page 2 at physrevlett.120.023901/figure_3.jpeg
# Saved figure_4.jpeg from page 2 at physrevlett.120.023901/figure_4.jpeg
# Saved figure_5.jpeg from page 2 at physrevlett.120.023901/figure_5.jpeg
# Saved figure_6.jpeg from page 4 at physrevlett.120.023901/figure_6.jpeg
# Saved figure_7.png from page 6 at physrevlett.120.023901/figure_7.png
# ['10.1021/jacs.7b11891', '10.1021/jacs.7b11891', '10.1021/jacs.7b11891', '10.1021/jacs.7b11891', '10.1021/jacs.7b11891', '10.1021/jacs.7b11891', '10.1021/jacs.7b11891', '10.1021/jacs.7b11891']
# Files generated in directory: out/jacs.7b11891
# Saved figure_1.png from page 1 at jacs.7b11891/figure_1.png
# Saved figure_2.png from page 2 at jacs.7b11891/figure_2.png
# Saved figure_3.png from page 3 at jacs.7b11891/figure_3.png
# Saved figure_4.png from page 3 at jacs.7b11891/figure_4.png
# Saved figure_5.png from page 4 at jacs.7b11891/figure_5.png
# Saved figure_6.png from page 5 at jacs.7b11891/figure_6.png
# Saved figure_7.png from page 6 at jacs.7b11891/figure_7.png
# ['10.1021/acs.macromol.7b02573', '10.1021/acs.macromol.7b02573', '10.1021/acs.macromol.7b02573', '10.1021/acs.macromol.7b02573', '10.1021/acs.macromol.7b02573', '10.1021/acs.macro', '10.1002/9783527603978.mst0434', '10.1021/acs.macromol.7b02573', '10.1021/acs.macromol.7b02573', '10.1021/acs.macromol.7b02573']
# Files generated in directory: out/acs.macromol.7b02573
# Saved figure_1.png from page 1 at acs.macromol.7b02573/figure_1.png
# Saved figure_2.png from page 2 at acs.macromol.7b02573/figure_2.png
# Saved figure_3.png from page 3 at acs.macromol.7b02573/figure_3.png
# Saved figure_4.png from page 3 at acs.macromol.7b02573/figure_4.png
# Saved figure_5.png from page 4 at acs.macromol.7b02573/figure_5.png
# Saved figure_6.png from page 5 at acs.macromol.7b02573/figure_6.png
# Saved figure_7.png from page 6 at acs.macromol.7b02573/figure_7.png
# ['10.1149/2.0981814jes']
# Files generated in directory: out/2.0981814jes
# Saved figure_1.png from page 1 at 2.0981814jes/figure_1.png
# Saved figure_2.png from page 1 at 2.0981814jes/figure_2.png
# Saved figure_3.jpeg from page 2 at 2.0981814jes/figure_3.jpeg
# Saved figure_4.jpeg from page 3 at 2.0981814jes/figure_4.jpeg
# Saved figure_5.jpeg from page 4 at 2.0981814jes/figure_5.jpeg
# Saved figure_6.jpeg from page 5 at 2.0981814jes/figure_6.jpeg
# Saved figure_7.jpeg from page 5 at 2.0981814jes/figure_7.jpeg
# Saved figure_8.jpeg from page 6 at 2.0981814jes/figure_8.jpeg
# Saved figure_9.jpeg from page 6 at 2.0981814jes/figure_9.jpeg
# Saved figure_10.jpeg from page 7 at 2.0981814jes/figure_10.jpeg
# Saved figure_11.jpeg from page 7 at 2.0981814jes/figure_11.jpeg
# Saved figure_12.png from page 8 at 2.0981814jes/figure_12.png
# ['10.1016/j.cplett.2018.05.021', '10.1103/PhysRevLett.7.118', '10.1007/978-3-662-02853-7', '10.1002/9781119998365', '10.1103/RevModPhys.88.015007', '10.1038/nature10721', '10.1038/nature14341', '10.1103/PhysRevLett.112.163901', '10.1103/PhysRevLett.120.023901', '10.1038/nature11340', '10.1103/PhysRevLett.7.229', '10.1038/17989', '10.1038/nmeth818', '10.1103/PhysRevA.94.043418', '10.1038/nphoton.2014.10', '10.1038/srep33292', '10.1103/PhysRevLett.106.083002', '10.1103/PhysRevA.71.023407', '10.1088/0022-3700/4/9/014', '10.1007/BF02819081', '10.1103/PhysRev.135.A51', '10.1117/12.2268152', '10.1107/S1600577515003380', '10.1038/nphoton.2012.233', '10.1038/nphoton.2013.277', '10.1107/S1600577515004580', '10.1103/PhysRevX.7.021043', '10.1063/1.4898315', '10.1103/PhysRevLett.113.153002', '10.1006/adnd.1993.1013', '10.1038/nphys1341']
# Files generated in directory: out/j.cplett.2018.05.021
# Saved figure_1.jpeg from page 2 at j.cplett.2018.05.021/figure_1.jpeg
# Saved figure_2.png from page 2 at j.cplett.2018.05.021/figure_2.png
# Saved figure_3.jpeg from page 3 at j.cplett.2018.05.021/figure_3.jpeg
# Saved figure_4.png from page 3 at j.cplett.2018.05.021/figure_4.png
# Saved figure_5.jpeg from page 4 at j.cplett.2018.05.021/figure_5.jpeg
# Saved figure_6.png from page 4 at j.cplett.2018.05.021/figure_6.png
# Saved figure_7.jpeg from page 5 at j.cplett.2018.05.021/figure_7.jpeg
# Saved figure_8.png from page 5 at j.cplett.2018.05.021/figure_8.png
# Saved figure_9.jpeg from page 6 at j.cplett.2018.05.021/figure_9.jpeg
# Saved figure_10.png from page 6 at j.cplett.2018.05.021/figure_10.png
# Saved figure_11.jpeg from page 7 at j.cplett.2018.05.021/figure_11.jpeg
# Saved figure_12.png from page 7 at j.cplett.2018.05.021/figure_12.png
# Saved figure_13.jpeg from page 8 at j.cplett.2018.05.021/figure_13.jpeg
# Saved figure_14.png from page 8 at j.cplett.2018.05.021/figure_14.png
# Saved figure_15.jpeg from page 9 at j.cplett.2018.05.021/figure_15.jpeg
# Saved figure_16.png from page 9 at j.cplett.2018.05.021/figure_16.png
# Saved figure_17.jpeg from page 10 at j.cplett.2018.05.021/figure_17.jpeg
# Saved figure_18.png from page 10 at j.cplett.2018.05.021/figure_18.png
# Saved figure_19.jpeg from page 11 at j.cplett.2018.05.021/figure_19.jpeg
# Saved figure_20.png from page 11 at j.cplett.2018.05.021/figure_20.png
# Saved figure_21.jpeg from page 12 at j.cplett.2018.05.021/figure_21.jpeg
# Saved figure_22.png from page 12 at j.cplett.2018.05.021/figure_22.png
# ['10.1021/jacs.8b09743', '10.1021/jacs.8b09743', '10.1021/jacs.8b09743', '10.1021/jacs.8b09743', '10.1021/jacs.8b09743', '10.1021/jacs.8b09743', '10.1021/jacs.8b09743', '10.1021/jacs.8b09743', '10.1021/jacs.8b09743']
# Files generated in directory: out/jacs.8b09743
# Saved figure_1.png from page 1 at jacs.8b09743/figure_1.png
# Saved figure_2.png from page 3 at jacs.8b09743/figure_2.png
# Saved figure_3.png from page 4 at jacs.8b09743/figure_3.png
# Saved figure_4.png from page 4 at jacs.8b09743/figure_4.png
# Saved figure_5.png from page 5 at jacs.8b09743/figure_5.png
# ['10.1021/acs.langmuir.8b03528', '10.1021/acs.langmuir.8b03528', '10.1021/acs.langmuir.8b03528', '10.1021/acs.langmuir.8b03528', '10.1021/acs.langmuir.8b03528', '10.1021/acs.langmuir.8b03528', '10.1021/acs.langmuir.8b03528', '10.1021/acs.langmuir.8b03528', '10.1021/acs.langmuir.8b03528', '10.1021/acs.langmuir.8b03528', '10.1021/acs.lang', '10.1021/acs.langmuir.8b03528', '10.1021/acs.langmuir.8b03528']
# Files generated in directory: out/acs.langmuir.8b03528
# Saved figure_1.png from page 1 at acs.langmuir.8b03528/figure_1.png
# Saved figure_2.png from page 2 at acs.langmuir.8b03528/figure_2.png
# Saved figure_3.png from page 3 at acs.langmuir.8b03528/figure_3.png
# Saved figure_4.png from page 5 at acs.langmuir.8b03528/figure_4.png
# Saved figure_5.png from page 6 at acs.langmuir.8b03528/figure_5.png
# Saved figure_6.png from page 7 at acs.langmuir.8b03528/figure_6.png
# Saved figure_7.png from page 7 at acs.langmuir.8b03528/figure_7.png
# Saved figure_8.png from page 8 at acs.langmuir.8b03528/figure_8.png
# Saved figure_9.png from page 8 at acs.langmuir.8b03528/figure_9.png
# Saved figure_10.png from page 9 at acs.langmuir.8b03528/figure_10.png
# ['10.1063/1.5109468', '10.1063/1.5109468', '10.1063/1.5109468', '10.1063/1.5109468', '10.1063/1.5109468', '10.1063/1.5109468', '10.1063/1.5109468', '10.1063/1.5109468', '10.1063/1.5109468', '10.1063/1.5109468']
# Files generated in directory: out/1.5109468
# Saved figure_1.png from page 1 at 1.5109468/figure_1.png
# Saved figure_2.png from page 1 at 1.5109468/figure_2.png
# Saved figure_3.png from page 1 at 1.5109468/figure_3.png
# Saved figure_4.png from page 1 at 1.5109468/figure_4.png
# Saved figure_5.png from page 1 at 1.5109468/figure_5.png
# Saved figure_6.png from page 1 at 1.5109468/figure_6.png
# Saved figure_7.png from page 1 at 1.5109468/figure_7.png
# Saved figure_8.jpeg from page 1 at 1.5109468/figure_8.jpeg
# Saved figure_9.jpeg from page 1 at 1.5109468/figure_9.jpeg
# Saved figure_10.png from page 1 at 1.5109468/figure_10.png
# Saved figure_11.png from page 2 at 1.5109468/figure_11.png
# Saved figure_12.png from page 2 at 1.5109468/figure_12.png
# Saved figure_13.png from page 2 at 1.5109468/figure_13.png
# Saved figure_14.png from page 2 at 1.5109468/figure_14.png
# Saved figure_15.png from page 4 at 1.5109468/figure_15.png
# Saved figure_16.png from page 5 at 1.5109468/figure_16.png
# Saved figure_17.png from page 6 at 1.5109468/figure_17.png
# Saved figure_18.png from page 6 at 1.5109468/figure_18.png
# ['10.1021/acs.jpclett.9b01835', '10.1021/acs.jpclett.9b01835', '10.1021/acs.jpclett.9b01835', '10.1021/acs.jp', '10.1021/acs.jpclett.9b01835', '10.1021/acs.jpclett.9b01835', '10.1039/c9sc00991d', '10.1021/acs.jpclett.9b01835']
# Files generated in directory: out/acs.jpclett.9b01835
# Saved figure_1.png from page 1 at acs.jpclett.9b01835/figure_1.png
# Saved figure_2.jpeg from page 1 at acs.jpclett.9b01835/figure_2.jpeg
# Saved figure_3.png from page 2 at acs.jpclett.9b01835/figure_3.png
# Saved figure_4.png from page 3 at acs.jpclett.9b01835/figure_4.png
# ['10.1016/j.cplett.2019.136811']
# Files generated in directory: out/j.cplett.2019.136811
# Saved figure_1.jpeg from page 1 at j.cplett.2019.136811/figure_1.jpeg
# Saved figure_2.jpeg from page 1 at j.cplett.2019.136811/figure_2.jpeg
# Saved figure_3.png from page 1 at j.cplett.2019.136811/figure_3.png
# Saved figure_4.jpeg from page 2 at j.cplett.2019.136811/figure_4.jpeg
# Saved figure_5.jpeg from page 3 at j.cplett.2019.136811/figure_5.jpeg
# ['10.1021/acsenergylett.0c00643', '10.1021/acsenergylett.0c00643', '10.1021/acsenergylett.0c00643', '10.1021/acsenergylett.0c00643', '10.1021/acsenergylett.0c00643', '10.1021/acsenergylett.0c00643', '10.1021/acsenergylett.0c00643', '10.1021/acsenergylett.0c00643', '10.1021/acsenergylett.0c00643', '10.1021/acsenergylett.0c00643', '10.1021/acsenergylett.0c00643', '10.1021/acsenergylett.0c00643']
# Files generated in directory: out/acsenergylett.0c00643
# Saved figure_1.png from page 1 at acsenergylett.0c00643/figure_1.png
# Saved figure_2.png from page 1 at acsenergylett.0c00643/figure_2.png
# Saved figure_3.png from page 1 at acsenergylett.0c00643/figure_3.png
# Saved figure_4.png from page 2 at acsenergylett.0c00643/figure_4.png
# Saved figure_5.png from page 3 at acsenergylett.0c00643/figure_5.png
# Saved figure_6.png from page 4 at acsenergylett.0c00643/figure_6.png
# Saved figure_7.png from page 5 at acsenergylett.0c00643/figure_7.png
# Saved figure_8.png from page 6 at acsenergylett.0c00643/figure_8.png
# ['10.1016/j.mattod.2020.09.035', '10.1016/j.mattod.2020.09.035', '10.1016/j.mattod.2020.09.035', '10.1016/j.mattod.2020.09.035', '10.1016/j.mattod.2020.09.035', '10.1016/j.mattod.2020.09.035', '10.1016/j.mattod.2020.09.035', '10.1016/j.mattod.2020.09.035', '10.1016/j.mattod.2020.09.035', '10.1016/j.mattod.2020.09.035', '10.1016/j.mattod.2020.09.035', '10.1016/j.mattod.2020.09.035', '10.1016/j.mattod.2020.09.035', '10.1016/j.mattod.2020.09.035']
# Files generated in directory: out/j.mattod.2020.09.035
# Saved figure_1.png from page 1 at j.mattod.2020.09.035/figure_1.png
# Saved figure_2.jpeg from page 1 at j.mattod.2020.09.035/figure_2.jpeg
# Saved figure_3.jpeg from page 2 at j.mattod.2020.09.035/figure_3.jpeg
# Saved figure_4.jpeg from page 3 at j.mattod.2020.09.035/figure_4.jpeg
# Saved figure_5.jpeg from page 4 at j.mattod.2020.09.035/figure_5.jpeg
# Saved figure_6.jpeg from page 5 at j.mattod.2020.09.035/figure_6.jpeg
# Saved figure_7.jpeg from page 5 at j.mattod.2020.09.035/figure_7.jpeg
# Saved figure_8.jpeg from page 6 at j.mattod.2020.09.035/figure_8.jpeg
# Saved figure_9.jpeg from page 6 at j.mattod.2020.09.035/figure_9.jpeg
# Saved figure_10.jpeg from page 6 at j.mattod.2020.09.035/figure_10.jpeg
# Saved figure_11.jpeg from page 7 at j.mattod.2020.09.035/figure_11.jpeg
# Saved figure_12.jpeg from page 7 at j.mattod.2020.09.035/figure_12.jpeg
# Saved figure_13.jpeg from page 8 at j.mattod.2020.09.035/figure_13.jpeg
# Saved figure_14.jpeg from page 8 at j.mattod.2020.09.035/figure_14.jpeg
# Saved figure_15.jpeg from page 9 at j.mattod.2020.09.035/figure_15.jpeg
# Saved figure_16.jpeg from page 9 at j.mattod.2020.09.035/figure_16.jpeg
# Saved figure_17.jpeg from page 10 at j.mattod.2020.09.035/figure_17.jpeg
# Saved figure_18.jpeg from page 10 at j.mattod.2020.09.035/figure_18.jpeg
# Saved figure_19.jpeg from page 10 at j.mattod.2020.09.035/figure_19.jpeg
# Saved figure_20.jpeg from page 11 at j.mattod.2020.09.035/figure_20.jpeg
# Saved figure_21.jpeg from page 12 at j.mattod.2020.09.035/figure_21.jpeg
# ['10.1038/s41560-021-00783-z', '10.1038/s41560-021-00783-z']
# Files generated in directory: out/s41560-021-00783-z
# Saved figure_1.jpeg from page 2 at s41560-021-00783-z/figure_1.jpeg
# Saved figure_2.jpeg from page 3 at s41560-021-00783-z/figure_2.jpeg
# Saved figure_3.jpeg from page 4 at s41560-021-00783-z/figure_3.jpeg
# Saved figure_4.jpeg from page 4 at s41560-021-00783-z/figure_4.jpeg
# Saved figure_5.jpeg from page 4 at s41560-021-00783-z/figure_5.jpeg
# Saved figure_6.jpeg from page 5 at s41560-021-00783-z/figure_6.jpeg
# Saved figure_7.jpeg from page 6 at s41560-021-00783-z/figure_7.jpeg
# Saved figure_8.jpeg from page 7 at s41560-021-00783-z/figure_8.jpeg
# Saved figure_9.jpeg from page 8 at s41560-021-00783-z/figure_9.jpeg
# Saved figure_10.jpeg from page 8 at s41560-021-00783-z/figure_10.jpeg
# Saved figure_11.png from page 10 at s41560-021-00783-z/figure_11.png
# ['10.1063/5.0047656', '10.1063/5.0047656', '10.1063/5.0047656', '10.1063/5.0047656', '10.1063/5.0047656', '10.1063/5.0047656', '10.1063/5.0047656', '10.1063/5.0047656', '10.1063/5.0047656', '10.1063/5.0047656', '10.1063/5.0047656', '10.1063/5.0047656', '10.1063/5.0047656', '10.1063/5.0047656', '10.1063/5.0047656', '10.1063/5.0047656', '10.1063/5.0047656', '10.1063/5.0047656']
# Files generated in directory: out/5.0047656
# Saved figure_1.png from page 1 at 5.0047656/figure_1.png
# Saved figure_2.png from page 1 at 5.0047656/figure_2.png
# Saved figure_3.png from page 1 at 5.0047656/figure_3.png
# Saved figure_4.png from page 1 at 5.0047656/figure_4.png
# Saved figure_5.png from page 1 at 5.0047656/figure_5.png
# Saved figure_6.png from page 1 at 5.0047656/figure_6.png
# Saved figure_7.png from page 1 at 5.0047656/figure_7.png
# Saved figure_8.jpeg from page 1 at 5.0047656/figure_8.jpeg
# Saved figure_9.jpeg from page 1 at 5.0047656/figure_9.jpeg
# Saved figure_10.png from page 1 at 5.0047656/figure_10.png
# Saved figure_11.png from page 2 at 5.0047656/figure_11.png
# Saved figure_12.png from page 2 at 5.0047656/figure_12.png
# Saved figure_13.png from page 2 at 5.0047656/figure_13.png
# Saved figure_14.png from page 2 at 5.0047656/figure_14.png
# Saved figure_15.png from page 3 at 5.0047656/figure_15.png
# Saved figure_16.png from page 7 at 5.0047656/figure_16.png
# Saved figure_17.png from page 12 at 5.0047656/figure_17.png
# ['10.1016/j.mechmat.2021.103903']
# Files generated in directory: out/j.mechmat.2021.103903
# Saved figure_1.jpeg from page 1 at j.mechmat.2021.103903/figure_1.jpeg
# Saved figure_2.jpeg from page 1 at j.mechmat.2021.103903/figure_2.jpeg
# Saved figure_3.png from page 1 at j.mechmat.2021.103903/figure_3.png
# Saved figure_4.jpeg from page 3 at j.mechmat.2021.103903/figure_4.jpeg
# Saved figure_5.jpeg from page 3 at j.mechmat.2021.103903/figure_5.jpeg
# Saved figure_6.jpeg from page 4 at j.mechmat.2021.103903/figure_6.jpeg
# Saved figure_7.jpeg from page 4 at j.mechmat.2021.103903/figure_7.jpeg
# Saved figure_8.jpeg from page 5 at j.mechmat.2021.103903/figure_8.jpeg
# Saved figure_9.jpeg from page 6 at j.mechmat.2021.103903/figure_9.jpeg
# Saved figure_10.jpeg from page 6 at j.mechmat.2021.103903/figure_10.jpeg
# Saved figure_11.jpeg from page 7 at j.mechmat.2021.103903/figure_11.jpeg
# Saved figure_12.jpeg from page 8 at j.mechmat.2021.103903/figure_12.jpeg
# ['10.6078/D1Z11P', '10.1126/sciadv.abe2265', '10.1126/sciadv.abe2265']
# Files generated in directory: out/sciadv.abe2265
# Saved figure_1.jpeg from page 2 at sciadv.abe2265/figure_1.jpeg
# Saved figure_2.png from page 3 at sciadv.abe2265/figure_2.png
# Saved figure_3.png from page 3 at sciadv.abe2265/figure_3.png
# Saved figure_4.png from page 6 at sciadv.abe2265/figure_4.png
# ['10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0', '10.1038/s41467-021-23603-0']
# Files generated in directory: out/s41467-021-23603-0
# Saved figure_1.jpeg from page 2 at s41467-021-23603-0/figure_1.jpeg
# Saved figure_2.jpeg from page 4 at s41467-021-23603-0/figure_2.jpeg
# Saved figure_3.jpeg from page 5 at s41467-021-23603-0/figure_3.jpeg
# Saved figure_4.jpeg from page 5 at s41467-021-23603-0/figure_4.jpeg
# Saved figure_5.jpeg from page 5 at s41467-021-23603-0/figure_5.jpeg
# Saved figure_6.png from page 5 at s41467-021-23603-0/figure_6.png
# Saved figure_7.png from page 6 at s41467-021-23603-0/figure_7.png
# Saved figure_8.png from page 9 at s41467-021-23603-0/figure_8.png
# ...
# Files generated in directory: out/acs.jpclett.2c03942
# Saved figure_1.png from page 1 at acs.jpclett.2c03942/figure_1.png
# Saved figure_2.png from page 1 at acs.jpclett.2c03942/figure_2.png
# Saved figure_3.png from page 1 at acs.jpclett.2c03942/figure_3.png
# Saved figure_4.png from page 1 at acs.jpclett.2c03942/figure_4.png
# Saved figure_5.png from page 1 at acs.jpclett.2c03942/figure_5.png
# Saved figure_6.png from page 1 at acs.jpclett.2c03942/figure_6.png
# Saved figure_7.png from page 1 at acs.jpclett.2c03942/figure_7.png
# Saved figure_8.png from page 1 at acs.jpclett.2c03942/figure_8.png
# Saved figure_9.png from page 2 at acs.jpclett.2c03942/figure_9.png
# Saved figure_10.png from page 3 at acs.jpclett.2c03942/figure_10.png
# Saved figure_11.png from page 4 at acs.jpclett.2c03942/figure_11.png
# ['10.1038/s41467-023-37857-3', '10.1038/s41467-023-37857-3', '10.1038/s41467-023-37857-3', '10.1038/s41467-023-37857-3', '10.1038/s41467-023-37857-3', '10.5281/zenodo.7739094', '10.5281/zenodo.7731073', '10.1038/s41467-023-37857-3', '10.1007/978-0-387', '10.1038/s41467-023-37857-3', '10.1038/s41467-023-37857-3']
# Files generated in directory: out/s41467-023-37857-3
# Saved figure_1.png from page 1 at s41467-023-37857-3/figure_1.png
# Saved figure_2.png from page 1 at s41467-023-37857-3/figure_2.png
# Saved figure_3.jpeg from page 2 at s41467-023-37857-3/figure_3.jpeg
# Saved figure_4.jpeg from page 2 at s41467-023-37857-3/figure_4.jpeg
# Saved figure_5.png from page 2 at s41467-023-37857-3/figure_5.png
# Saved figure_6.jpeg from page 3 at s41467-023-37857-3/figure_6.jpeg
# Saved figure_7.jpeg from page 3 at s41467-023-37857-3/figure_7.jpeg
# Saved figure_8.jpeg from page 3 at s41467-023-37857-3/figure_8.jpeg
# Saved figure_9.png from page 3 at s41467-023-37857-3/figure_9.png
# Saved figure_10.jpeg from page 3 at s41467-023-37857-3/figure_10.jpeg
# Saved figure_11.png from page 4 at s41467-023-37857-3/figure_11.png
# Saved figure_12.jpeg from page 4 at s41467-023-37857-3/figure_12.jpeg
# ['10.1038/s41563-023-01535-y', '10.1038/s41563-023-01535-y', '10.1038/s41563-023-01535-y', '10.1038/s41563-023-01535-y', '10.1038/s41563-023-01535-y', '10.1038/s41563-023-01535-y', '10.1109/PES.2008.4596576', '10.1038/s41563-023-01535-y', '10.6078/D1N41X', '10.1038/s41563-023-01535-y', '10.1038/s41563-023-01535-y']
# Files generated in directory: out/s41563-023-01535-y
# Saved figure_1.png from page 1 at s41563-023-01535-y/figure_1.png
# Saved figure_2.png from page 1 at s41563-023-01535-y/figure_2.png
# Saved figure_3.jpeg from page 2 at s41563-023-01535-y/figure_3.jpeg
# Saved figure_4.jpeg from page 2 at s41563-023-01535-y/figure_4.jpeg
# Saved figure_5.jpeg from page 2 at s41563-023-01535-y/figure_5.jpeg
# Saved figure_6.jpeg from page 2 at s41563-023-01535-y/figure_6.jpeg
# Saved figure_7.jpeg from page 2 at s41563-023-01535-y/figure_7.jpeg
# Saved figure_8.jpeg from page 2 at s41563-023-01535-y/figure_8.jpeg
# Saved figure_9.jpeg from page 3 at s41563-023-01535-y/figure_9.jpeg
# Saved figure_10.jpeg from page 3 at s41563-023-01535-y/figure_10.jpeg
# Saved figure_11.png from page 4 at s41563-023-01535-y/figure_11.png
# Saved figure_12.jpeg from page 4 at s41563-023-01535-y/figure_12.jpeg
# Saved figure_13.jpeg from page 4 at s41563-023-01535-y/figure_13.jpeg
# Saved figure_14.jpeg from page 4 at s41563-023-01535-y/figure_14.jpeg
# Saved figure_15.jpeg from page 4 at s41563-023-01535-y/figure_15.jpeg
# ['10.1021/acs.nanolett.3c01825', '10.1021/acs.nanolett.3c01825', '10.1021/acs.nanolett.3c01825', '10.1021/acs.nanolett.3c01825', '10.1021/acs.nanolett.3c01825', '10.1021/acs.nanolett.3c01825', '10.1021/acs.nanolett.3c01825', '10.1021/acs.nanolett.3c01825', '10.1021/acs.nanolett.3c01825', '10.1021/acs.nanolett.3c01825', '10.1021/acs.nanolett.3c01825']
# Files generated in directory: out/acs.nanolett.3c01825
# Saved figure_1.png from page 1 at acs.nanolett.3c01825/figure_1.png
# Saved figure_2.png from page 1 at acs.nanolett.3c01825/figure_2.png
# Saved figure_3.png from page 2 at acs.nanolett.3c01825/figure_3.png
# Saved figure_4.png from page 3 at acs.nanolett.3c01825/figure_4.png
# Saved figure_5.png from page 4 at acs.nanolett.3c01825/figure_5.png
# Saved figure_6.png from page 5 at acs.nanolett.3c01825/figure_6.png
# Saved figure_7.png from page 6 at acs.nanolett.3c01825/figure_7.png
# ['10.1021/acsami.3c09627', '10.1021/acsami.3c09627', '10.1021/acsami.3c09627', '10.1021/acsami.3c09627', '10.1021/acsami.3c09627', '10.1021/acsami.3c09627', '10.1021/acsami.3c09627', '10.1021/acsami.3c09627', '10.1021/acsami.3c09627', '10.1021/acsami.3c09627', '10.1021/acsami.3c09627', '10.1021/acsami.3c09627', '10.1021/acsami.3c09627', '10.1021/acsami.3c09627']
# Files generated in directory: out/acsami.3c09627
# Saved figure_1.png from page 1 at acsami.3c09627/figure_1.png
# Saved figure_2.png from page 1 at acsami.3c09627/figure_2.png
# Saved figure_3.png from page 2 at acsami.3c09627/figure_3.png
# Saved figure_4.png from page 3 at acsami.3c09627/figure_4.png
# Saved figure_5.png from page 4 at acsami.3c09627/figure_5.png
# Saved figure_6.png from page 6 at acsami.3c09627/figure_6.png
# Saved figure_7.png from page 7 at acsami.3c09627/figure_7.png
# ['10.1021/acsami.3c07224', '10.1021/acsami.3c07224', '10.1021/acsami.3c07224', '10.1021/acsami.3c07224', '10.1021/acsami.3c07224', '10.1021/acsami.3c07224', '10.1021/acsami.3c07224', '10.1021/acsami.3c07224', '10.1021/acsami.3c07224', '10.1021/acsami.3c07224', '10.1021/acsami.3c07224', '10.1021/acsami.3c07224', '10.1021/acsami.3c07224']
# Files generated in directory: out/acsami.3c07224
# Saved figure_1.png from page 1 at acsami.3c07224/figure_1.png
# Saved figure_2.png from page 1 at acsami.3c07224/figure_2.png
# Saved figure_3.png from page 2 at acsami.3c07224/figure_3.png
# Saved figure_4.png from page 3 at acsami.3c07224/figure_4.png
# Saved figure_5.png from page 4 at acsami.3c07224/figure_5.png
# Saved figure_6.png from page 5 at acsami.3c07224/figure_6.png
# Saved figure_7.png from page 6 at acsami.3c07224/figure_7.png
# Saved figure_8.png from page 7 at acsami.3c07224/figure_8.png
# ['10.1073/pnas', '10.1073/pnas.2310714120', '10.1073/pnas.2310714120', '10.1073/pnas.2310714120', '10.1073/pnas.2310714120', '10.1073/pnas.2310714120', '10.1073/pnas.2310714120', '10.1073/pnas.2310714120', '10.1073/pnas.2310714120', '10.1073/pnas.2310714120', '10.1073/pnas.2310714120', '10.1038/s41560-0', '10.1073/pnas.2310714120']
# Files generated in directory: out/pnas.2310714120
# Saved figure_1.jpeg from page 2 at pnas.2310714120/figure_1.jpeg
# Saved figure_2.png from page 3 at pnas.2310714120/figure_2.png
# Saved figure_3.png from page 5 at pnas.2310714120/figure_3.png
# Saved figure_4.png from page 6 at pnas.2310714120/figure_4.png
# Saved figure_5.png from page 7 at pnas.2310714120/figure_5.png
# Saved figure_6.png from page 9 at pnas.2310714120/figure_6.png
# ['10.1021/jacs.3c05093', '10.1021/jacs.3c05093', '10.1021/jacs.3c05093', '10.1021/jacs.3c05093', '10.1021/jacs.3c05093', '10.1021/jacs.3c05093', '10.1021/jacs.3c05093', '10.1021/jacs.3c05093', '10.1021/jacs.3c05093', '10.1021/jacs.3c05093', '10.5281/zeno', '10.26434/chemrxiv-2023-74vpv', '10.1021/jacs.3c05093', '10.1007/BF00203187', '10.1021/jacs.3c05093', '10.1021/jacs.3c05093']
# Files generated in directory: out/jacs.3c05093
# Saved figure_1.png from page 1 at jacs.3c05093/figure_1.png
# Saved figure_2.png from page 1 at jacs.3c05093/figure_2.png
# Saved figure_3.png from page 3 at jacs.3c05093/figure_3.png
# Saved figure_4.png from page 4 at jacs.3c05093/figure_4.png
# Saved figure_5.png from page 5 at jacs.3c05093/figure_5.png
# Saved figure_6.png from page 6 at jacs.3c05093/figure_6.png
# ['10.1002/anie.202316786', '10.1002/anie.202316786', '10.1002/anie.202316786', '10.1002/anie.202316786', '10.1002/anie.202316786', '10.1002/anie.202316786', '10.1002/anie.202316786', '10.1002/anie.202316786', '10.1002/anie.202316786', '10.1002/anie.202316786', '10.1002/anie.202316786', '10.1002/anie.202316786', '10.1002/anie.202316786', '10.1002/anie.202316786', '10.1002/anie.202316786', '10.1002/anie.202316786', '10.1002/anie.202316786', '10.1002/anie.202316786', '10.1002/anie.202316786', '10.1002/anie.202316786', '10.1002/anie.202316786']
# Files generated in directory: out/anie.202316786
# Saved figure_1.png from page 1 at anie.202316786/figure_1.png
# Saved figure_2.png from page 1 at anie.202316786/figure_2.png
# Saved figure_3.png from page 1 at anie.202316786/figure_3.png
# Saved figure_4.png from page 2 at anie.202316786/figure_4.png
# Saved figure_5.png from page 2 at anie.202316786/figure_5.png
# Saved figure_6.png from page 3 at anie.202316786/figure_6.png
# Saved figure_7.png from page 3 at anie.202316786/figure_7.png
# Saved figure_8.png from page 4 at anie.202316786/figure_8.png
# Saved figure_9.jpeg from page 4 at anie.202316786/figure_9.jpeg
# Saved figure_10.png from page 4 at anie.202316786/figure_10.png
# Saved figure_11.jpeg from page 5 at anie.202316786/figure_11.jpeg
# Saved figure_12.png from page 5 at anie.202316786/figure_12.png
# Saved figure_13.png from page 5 at anie.202316786/figure_13.png
# Saved figure_14.png from page 6 at anie.202316786/figure_14.png
# Saved figure_15.jpeg from page 6 at anie.202316786/figure_15.jpeg
# Saved figure_16.png from page 6 at anie.202316786/figure_16.png
# Saved figure_17.png from page 7 at anie.202316786/figure_17.png
# Saved figure_18.png from page 7 at anie.202316786/figure_18.png
# Saved figure_19.png from page 8 at anie.202316786/figure_19.png
# Saved figure_20.jpeg from page 8 at anie.202316786/figure_20.jpeg
# Saved figure_21.png from page 8 at anie.202316786/figure_21.png
# Saved figure_22.png from page 9 at anie.202316786/figure_22.png
# Saved figure_23.png from page 9 at anie.202316786/figure_23.png
# Saved figure_24.png from page 10 at anie.202316786/figure_24.png
# Saved figure_25.png from page 10 at anie.202316786/figure_25.png
# Saved figure_26.jpeg from page 11 at anie.202316786/figure_26.jpeg
# Saved figure_27.png from page 11 at anie.202316786/figure_27.png
# Saved figure_28.png from page 11 at anie.202316786/figure_28.png
# Main versions of papers:
# Paper 001: 001.nar-6047.full.pdf
# Paper 002: 002.BioPhysJ-2006-1463.pdf
# Paper 003: 003.NanoSciNanoTech.707.pdf
# Paper 004: 004.jbc-8829-36.pdf
# Paper 005: 005.jbc-15835-46.pdf
# Paper 006: 006.BioChem.bi901283p.pdf
# Paper 007: 007.cphc_201000528.pdf
# Paper 008: 008.JChemPhys_133_134114.pdf
# Paper 009: 009.jbc-37753-61.pdf
# Paper 010: 010.jz101391r.pdf
# Paper 011: 011.c0cp01549k.pdf
# Paper 012: 012.jz200453u.pdf
# Paper 013: 013.nl104227t.pdf
# Paper 014: 014.ct200211b.pdf
# Paper 015: 015.jz200760n.pdf
# Paper 016: 016.pnas.1108073108.pdf
# Paper 017: 017.jp209541e.pdf
# Paper 018: 018.jz201612y.pdf
# Paper 019: 019.jz3000036.pdf
# Paper 020: 020.jp301610b.pdf
# Paper 021: 021.jp306473u.pdf
# Paper 022: 022.jp309693d.pdf
# Paper 023: 023.025248JCP.pdf
# Paper 024: 024.jp310422q.pdf
# Paper 025: 025.commmat_4952.pdf
# Paper 026: 026.066401JCP.pdf
# Paper 027: 027.jz500260s.pdf
# Paper 028: 028.jecs.A1100-6.pdf
# Paper 029: 029.jp410861h.pdf
# Paper 030: 030.science.831.full.pdf
# Paper 031: 031.C4CP05316H.pdf
# Paper 032: 032.nature14327.pdf
# Paper 033: 033.aenm.201500285.pdf
# Paper 034: 034.c5cp02951a.pdf
# Paper 035: 035.nl5b02078.pdf
# Paper 036: 036.c6cp03940e1.pdf
# Paper 037: 037.jp6b04264.pdf
# Paper 038: 038.JECS-2017-Wujcik-A18-27.pdf
# Paper 039: 039.c6cp06889h.pdf
# Paper 040: 040.nlE7b00249.pdf
# Paper 041: 041.acs.jpcc.7b05153.pdf
# Paper 042: 042.s41467-017-02410-6.pdf
# Paper 043: 043.PhysRevLett.120.023901.pdf
# Paper 044: 044.jacs.7b11891.pdf
# Paper 045: 045.acs.macromol.7b02573.pdf
# Paper 046: 046.J. Electrochem. Soc.-2018-Wang-A3487-95.pdf
# Paper 047: 047.qt3xn0326x.pdf
# Paper 048: 048.jacs.8b09743.pdf
# Paper 049: 049.acs.langmuir.8b03528.pdf
# Paper 050: 050.1.5109468.pdf
# Paper 051: 051.acs.jpclett.9b01835.pdf
# Paper 052: 052.j.cplett.2019.136811.pdf
# Paper 053: 053.acsenergylett.0c00643.pdf
# Paper 054: 054.1-s2.0-S1369702120303382-main.pdf
# Paper 055: 055.s41560-021-00783-z.pdf
# Paper 056: 056.jcp.5.0047656.pdf
# Paper 057: 057.1-s2.0-S0167663621001502-main.pdf
# Paper 058: 058.eabe2265.full.pdf
# Paper 059: 059.s41467-021-23603-0.pdf
# Paper 060: 060.jcp5.0054314.pdf
# Paper 061: 061.acs.nanolett.1c01502.pdf
# Paper 062: 062.jacs.1c04272.pdf
# Paper 063: 063.PhysRevLett.127.096801.pdf
# Paper 064: 064.acs.jpclett.1c02609.ms.pdf
# Paper 065: 065.1-s2.0-S0378775321009617-main.pdf
# Paper 066: 066.PhysRevLett.127.237402.pdf
# Paper 067: 067.1-s2.0-S2666386421004537-main.pdf
# Paper 068: 068.acsenergylett.1c02723.pdf
# Paper 069: 069.d1ee03422g.pdf
# Paper 070: 070.acs.nanolett.2c00047.pdf
# Paper 071: 071.acs.jpclett.2c00770.pdf
# Paper 072: 072.pnas.2200392119.pdf
# Paper 073: 073.acsnano.2c04595.pdf
# Paper 074: 074.acs.chemmater.2c00292.pdf
# Paper 075: 075.acs.jpclett.2c01020.pdf
# Paper 076: 076.PhysRevApplied.18.054031.pdf
# Paper 077: 077.acsanm.2c05257.pdf
# Paper 078: 078.d2nr05732h.ms.pdf
# Paper 079: 079.acs.jpcb.2c08843.ms.pdf
# Paper 080: 080.acs.jpclett.2c03942.pdf
# Paper 081: 081.s41467-023-37857-3.pdf
# Paper 082: 082.s41563-023-01535-y.pdf
# Paper 083: 083.acs.nanolett.3c01825.ms.pdf
# Paper 084: 084.acsami.3c09627.pdf
# Paper 085: 085.acsami.3c07224.ms.pdf
# Paper 086: 086.pnas.2310714120.ms.pdf
# Paper 087: 087.jacs.3c05093.ms.pdf
# Paper 088: 088.anie202316786-ms.pdf
# Sup versions of papers:
# Paper 006: 006.BioChem.bi901283p_Sm.pdf
# Paper 007: 007.cphc_201000528_sm_miscellaneous_information.pdf
# Paper 008: 008.JChemPhys_133_134114_SM.pdf
# Paper 009: 009.jbc-37753-61_SM.pdf
# Paper 011: 011.c0cp01549k_SM.pdf
# Paper 012: 012.jz200453u_si_001.pdf
# Paper 013: 013.nl104227t_si_002.pdf
# Paper 015: 015.jz200760n_si_001.pdf
# Paper 016: 016.pnas.1108073108_SI.pdf
# Paper 017: 017.jp209541e_si_001.pdf
# Paper 018: 018.jz201612y_si_001.pdf
# Paper 019: 019.jz3000036_si_001.pdf
# Paper 020: 020.jp301610b_si_001.pdf
# Paper 021: 021.jp306473u_si_001.pdf
# Paper 024: 024.jp310422q_si_001.pdf
# Paper 027: 027.jz500260s_si.pdf
# Paper 029: 029.jp410861h_si_001.pdf
# Paper 030: 030.science.831.SM.pdf
# Paper 032: 032.nature14327-s1.pdf
# Paper 034: 034.c5cp02951a.SM.pdf
# Paper 035: 035.nl5b02078_si_001.pdf
# Paper 036: 036.c6cp03940e1_si.pdf
# Paper 037: 037.jp6b04264_si_001.pdf
# Paper 039: 039.c6cp06889h1_si.pdf
# Paper 040: 040.nlE7b00249_si.pdf
# Paper 041: 041.acs.jp7b05153_si_001.pdf
# Paper 042: 042.s41467-017-02410-6-SI.pdf
# Paper 043: 043.PhysRevLett.120.023901-SI.pdf
# Paper 044: 044.ja7b11891_si_001.pdf
# Paper 045: 045.ma7b02573_si_001.pdf
# Paper 046: 046.J. Electrochem. Soc.-2018-Wang-A3487-95-SI.pdf
# Paper 048: 048.ja8b09743_si_001.pdf
# Paper 049: 049.acs.langmuir.8b03528_si_001.pdf
# Paper 050: 050.1.5109468-sm.pdf
# Paper 051: 051.jz9b01835_si_001.pdf
# Paper 053: 053.acsenergylett.0c00643.si.pdf
# Paper 054: 054.1-s2.0-S1369702120303382-mmc1.pdf
# Paper 055: 055.s41560-021-00783-z-SI.pdf
# Paper 056: 056.jcp.5.0047656-si.pdf
# Paper 058: 058.abe2265_SM.pdf
# Paper 059: 059.s41467_2021_23603_MOESM1_ESM.pdf;059.s41467_2021_23603_MOESM5_ESM.pdf
# Paper 060: 060.jcp5.0054314-si.pdf
# Paper 061: 061.nl1c01502_si_001.pdf
# Paper 062: 062.ja1c04272_si_001.pdf
# Paper 063: 063.PhysRevLett.127.096801-si.pdf
# Paper 064: 064.acs.jpclett.1c02609.si.pdf
# Paper 065: 065.1-s2.0-S0378775321009617-si.pdf
# Paper 066: 066.PhysRevLett.127.237402.si.pdf
# Paper 067: 067.1-s2.0-S2666386421004537-mmc1.pdf
# Paper 068: 068.acsenergylett.1c02723_si.pdf
# Paper 069: 069.d1ee03422g.si.pdf
# Paper 070: 070.acs.nanolett.2c00047.si.pdf
# Paper 071: 071.jz2c00770_si_001.pdf
# Paper 072: 072.pnas.2200392119.sapp.pdf
# Paper 073: 073.acsnano.2c04595_si_001.pdf
# Paper 075: 075.jz2c01020_si_002.pdf;075.jz2c01020_si_001.pdf
# Paper 077: 077.an2c05257_si_001.pdf
# Paper 078: 078.d2nr05732h.si.pdf
# Paper 079: 079.acs.jpcb.2c08843.si.pdf
# Paper 080: 080.acs.jpclett.2c03942.si.1.pdf;080.acs.jpclett.2c03942.si.2.pdf
# Paper 081: 081.41467_2023_37857_MOESM1_ESM.pdf
# Paper 082: 082.s41563-023-01535-y_ESM.pdf
# Paper 083: 083.acs.nanolett.3c01825.si.pdf
# Paper 084: 084.acsami.3c09627_si_001.pdf
# Paper 085: 085.acsami.3c07224.si.pdf
# Paper 086: 086.pnas.2310714120.sapp.pdf
# Paper 087: 087.jacs.3c05093.si.pdf
# Paper 088: 088.anie202316786-si.pdf

# %%
directory = "test"
main_versions, supplementary_versions = create_files_with_main_and_supplementary_versions_test(directory)
print("Main versions of papers:")
for paper_number, filename in main_versions.items():
    print(f"Paper {paper_number}: {filename}")

print("Sup versions of papers:")
for paper_number, file_path in supplementary_versions.items():
    print(f"Paper {paper_number}: {file_path}")
# Out:
# ['10.1021/bi901283p']
# Files generated in directory: out/bi901283p
# Saved figure_1.png from page 2 at test/figure_1.png
# Saved figure_2.png from page 2 at test/figure_2.png
# Saved figure_3.png from page 3 at test/figure_3.png
# Saved figure_4.png from page 4 at test/figure_4.png
# Saved figure_5.png from page 5 at test/figure_5.png
# Saved figure_6.png from page 5 at test/figure_6.png
# Saved figure_7.png from page 5 at test/figure_7.png
# Saved figure_8.png from page 6 at test/figure_8.png
# Saved figure_9.png from page 6 at test/figure_9.png
# Main versions of papers:
# Paper 001: 001.BioChem.bi901283p.pdf
# Sup versions of papers:
# Paper 001: 001.BioChem.bi901283p_Sm.pdf

# %%
import fitz  # PyMuPDF
import os

def extract_and_mark_figures(pdf_path, output_directory):
    doc = fitz.open(pdf_path)
    figure_counter = 1

    # Create the output directory if it doesn't exist
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    for page_number in range(len(doc)):
        page = doc[page_number]
        image_list = page.get_images(full=True)  # Image references

        # Extract and save each image
        for img_index, img_info in enumerate(image_list):
            xref = img_info[0]
            base_image = doc.extract_image(xref)
            image_bytes = base_image["image"]
            image_ext = base_image["ext"]

            image_filename = f"figure_{figure_counter}.{image_ext}"
            image_path = os.path.join(output_directory, image_filename)

            with open(image_path, "wb") as img_file:
                img_file.write(image_bytes)

            print(f"Saved {image_filename} from page {page_number + 1} at {image_path}")
            figure_counter += 1

    doc.close()

pdf_path = './test/001.BioChem.bi901283p.pdf'
output_directory = './test'
extract_and_mark_figures(pdf_path, output_directory)
# Out:
# Saved figure_1.png from page 2 at ./test/figure_1.png
# Saved figure_2.png from page 2 at ./test/figure_2.png
# Saved figure_3.png from page 3 at ./test/figure_3.png
# Saved figure_4.png from page 4 at ./test/figure_4.png
# Saved figure_5.png from page 5 at ./test/figure_5.png
# Saved figure_6.png from page 5 at ./test/figure_6.png
# Saved figure_7.png from page 5 at ./test/figure_7.png
# Saved figure_8.png from page 6 at ./test/figure_8.png
# Saved figure_9.png from page 6 at ./test/figure_9.png
